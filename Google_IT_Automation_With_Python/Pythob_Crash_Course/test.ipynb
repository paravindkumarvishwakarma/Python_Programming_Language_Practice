# %%
file_path = r"C:\Users\paravind\Downloads\Assets Master_Padam Final 02 Jan 2026.xlsx"  # replace with your file path

with open(file_path, "r", encoding="utf-8") as file:
    content = file.read()

print(content)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 4
#       1 file_path = r"C:\Users\paravind\Downloads\Assets Master_Padam Final 02 Jan 2026.xlsx"  # replace with your file path
#       3 with open(file_path, "r", encoding="utf-8") as file:
# ----> 4     content = file.read()
#       6 print(content)
#
# File <frozen codecs>:325, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 14-15: invalid continuation byte
