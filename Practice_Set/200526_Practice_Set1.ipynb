# %% [markdown]
# # 140+ Basic Python Programs - Practice Notebook
# This interactive worksheet is adapted from your interview preparation handbook. The answers/solutions have been stripped out to allow you to practice writing the code fresh.

# %% [markdown]
# ### Program 1
# **Task:** Write a Python program to print "Hello Python".

# %%
# Write your solution here

# %% [markdown]
# ### Program 2
# **Task:** Write a Python program to do arithmetical operations addition and division.

# %%
# Write your solution here

# %% [markdown]
# ### Program 3
# **Task:** Write a Python program to find the area of a triangle.

# %%
# Write your solution here

# %% [markdown]
# ### Program 4
# **Task:** Write a Python program to swap two variables.

# %%
# Write your solution here

# %% [markdown]
# ### Program 5
# **Task:** Write a Python program to generate a random number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 6
# **Task:** Write a Python program to convert kilometers to miles.

# %%
# Write your solution here

# %% [markdown]
# ### Program 7
# **Task:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Write your solution here

# %% [markdown]
# ### Program 8
# **Task:** Write a Python program to display calendar.

# %%
# Write your solution here

# %% [markdown]
# ### Program 9
# **Task:** Write a Python program to solve quadratic equation.

# %%
# Write your solution here

# %% [markdown]
# ### Program 10
# **Task:** Write a Python program to swap two variables without temp variable.

# %%
# Write your solution here

# %% [markdown]
# ### Program 11
# **Task:** Write a Python Program to Check if a Number is Positive, Negative or Zero.

# %%
# Write your solution here

# %% [markdown]
# ### Program 12
# **Task:** Write a Python Program to Check if a Number is Odd or Even.

# %%
# Write your solution here

# %% [markdown]
# ### Program 13
# **Task:** Write a Python Program to Check Leap Year.

# %%
# Write your solution here

# %% [markdown]
# ### Program 14
# **Task:** Write a Python Program to Check Prime Number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 15
# **Task:** Write a Python Program to Print all Prime Numbers in an Interval of 1-10.

# %%
# Write your solution here

# %% [markdown]
# ### Program 16
# **Task:** Write a Python Program to Find the Factorial of a Number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 17
# **Task:** Write a Python Program to Display the multiplication Table.

# %%
# Write your solution here

# %% [markdown]
# ### Program 18
# **Task:** Write a Python Program to Print the Fibonacci sequence.

# %%
# Write your solution here

# %% [markdown]
# ### Program 19
# **Task:** Write a Python Program to Check Armstrong Number?

# %%
# Write your solution here

# %% [markdown]
# ### Program 20
# **Task:** Write a Python Program to Find Armstrong Number in an Interval.

# %%
# Write your solution here

# %% [markdown]
# ### Program 21
# **Task:** Write a Python Program to Find the Sum of Natural Numbers.

# %%
# Write your solution here

# %% [markdown]
# ### Program 22
# **Task:** Write a Python Program to Find LCM.

# %%
# Write your solution here

# %% [markdown]
# ### Program 23
# **Task:** Write a Python Program to Find HCF.

# %%
# Write your solution here

# %% [markdown]
# ### Program 24
# **Task:** Write a Python Program to Convert Decimal to Binary, Octal and Hexadecimal.

# %%
# Write your solution here

# %% [markdown]
# ### Program 25
# **Task:** Write a Python Program To Find ASCII value of a character.

# %%
# Write your solution here

# %% [markdown]
# ### Program 26
# **Task:** Write a Python Program to Make a Simple Calculator with 4 basic mathematical operations.

# %%
# Write your solution here

# %% [markdown]
# ### Program 27
# **Task:** Write a Python Program to Display Fibonacci Sequence Using Recursion.

# %%
# Write your solution here

# %% [markdown]
# ### Program 28
# **Task:** Write a Python Program to Find Factorial of Number Using Recursion.

# %%
# Write your solution here

# %% [markdown]
# ### Program 29
# **Task:** Write a Python Program to calculate your Body Mass Index.

# %%
# Write your solution here

# %% [markdown]
# ### Program 30
# **Task:** Write a Python Program to calculate the natural logarithm of any number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 31
# **Task:** Write a Python Program for cube sum of first n natural numbers?

# %%
# Write your solution here

# %% [markdown]
# ### Program 32
# **Task:** Write a Python Program to find sum of array.

# %%
# Write your solution here

# %% [markdown]
# ### Program 33
# **Task:** Write a Python Program to find largest element in an array.

# %%
# Write your solution here

# %% [markdown]
# ### Program 34
# **Task:** Write a Python Program for array rotation.

# %%
# Write your solution here

# %% [markdown]
# ### Program 35
# **Task:** Write a Python Program to Split the array and add the first part to the end?

# %%
# Write your solution here

# %% [markdown]
# ### Program 36
# **Task:** Write a Python Program to check if given array is Monotonic.

# %%
# Write your solution here

# %% [markdown]
# ### Program 37
# **Task:** Write a Python Program to Add Two Matrices.

# %%
# Write your solution here

# %% [markdown]
# ### Program 38
# **Task:** Write a Python Program to Multiply Two Matrices.

# %%
# Write your solution here

# %% [markdown]
# ### Program 39
# **Task:** Write a Python Program to Transpose a Matrix.

# %%
# Write your solution here

# %% [markdown]
# ### Program 40
# **Task:** Write a Python Program to Sort Words in Alphabetic Order.

# %%
# Write your solution here

# %% [markdown]
# ### Program 41
# **Task:** Write a Python Program to Remove Punctuation From a String.

# %%
# Write your solution here

# %% [markdown]
# ### Program 43
# **Task:** Write a Python program to check if the given number is a Disarium Number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 44
# **Task:** Write a Python program to print all disarium numbers between 1 to 100.

# %%
# Write your solution here

# %% [markdown]
# ### Program 45
# **Task:** Write a Python program to check if the given number is Happy Number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 46
# **Task:** Write a Python program to print all happy numbers between 1 and 100.

# %%
# Write your solution here

# %% [markdown]
# ### Program 47
# **Task:** Write a Python program to determine whether the given number is a Harshad Number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 48
# **Task:** Write a Python program to print all pronic numbers between 1 and 100.

# %%
# Write your solution here

# %% [markdown]
# ### Program 50
# **Task:** Write a Python program to Multiply all numbers in the list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 51
# **Task:** Write a Python program to find smallest number in a list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 52
# **Task:** Write a Python program to find largest number in a list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 53
# **Task:** Write a Python program to find second largest number in a list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 54
# **Task:** Write a Python program to find N largest elements from a list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 57
# **Task:** Write a Python program to Remove empty List from List.

# %%
# Write your solution here

# %% [markdown]
# ### Program 58
# **Task:** Write a Python program to Cloning or Copying a list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 59
# **Task:** Write a Python program to Count occurrences of an element in a list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 60
# **Task:** Write a Python program to find words which are greater than given length k.

# %%
# Write your solution here

# %% [markdown]
# ### Program 61
# **Task:** Write a Python program for removing ith character from a string.

# %%
# Write your solution here

# %% [markdown]
# ### Program 62
# **Task:** Write a Python program to split and join a string.

# %%
# Write your solution here

# %% [markdown]
# ### Program 63
# **Task:** Write a Python program to check if a given string is binary string or not.

# %%
# Write your solution here

# %% [markdown]
# ### Program 64
# **Task:** Write a Python program to find uncommon words from two Strings.

# %%
# Write your solution here

# %% [markdown]
# ### Program 65
# **Task:** Write a Python program to find all duplicate characters in string.

# %%
# Write your solution here

# %% [markdown]
# ### Program 66
# **Task:** Write a Python Program to check if a string contains any special character.

# %%
# Write your solution here

# %% [markdown]
# ### Program 67
# **Task:** Write a Python program to Extract Unique dictionary values.

# %%
# Write your solution here

# %% [markdown]
# ### Program 68
# **Task:** Write a Python program to find the sum of all items in a dictionary.

# %%
# Write your solution here

# %% [markdown]
# ### Program 70
# **Task:** Write a Python program to convert key-values list to flat dictionary.

# %%
# Write your solution here

# %% [markdown]
# ### Program 71
# **Task:** Write a Python program to insertion at the beginning in OrderedDict.

# %%
# Write your solution here

# %% [markdown]
# ### Program 72
# **Task:** Write a Python program to check order of character in string using OrderedDict().

# %%
# Write your solution here

# %% [markdown]
# ### Program 73
# **Task:** Write a Python program to sort Python Dictionaries by Key or Value.

# %%
# Write your solution here

# %% [markdown]
# ### Program 74
# **Task:** Write a program that calculates and prints the value according to the given formula: Q = Square root of (2CD/H). Fixed values: C=50, H=30.

# %%
# Write your solution here

# %% [markdown]
# ### Program 75
# **Task:** Write a program which takes 2 digits, X,Y as input and generates a 2-dimensional array where element value in i-th row and j-th column is i*j.

# %%
# Write your solution here

# %% [markdown]
# ### Program 76
# **Task:** Write a program that accepts a comma separated sequence of words as input and prints the words in a comma-separated sequence after sorting them alphabetically.

# %%
# Write your solution here

# %% [markdown]
# ### Program 77
# **Task:** Write a program that accepts a sequence of whitespace separated words as input and prints the words after removing all duplicate words and sorting them alphanumerically.

# %%
# Write your solution here

# %% [markdown]
# ### Program 79
# **Task:** Write a program that accepts a sentence and calculate the number of letters and digits.

# %%
# Write your solution here

# %% [markdown]
# ### Program 80
# **Task:** Write a program to check the validity of password input by users against specified criteria.

# %%
# Write your solution here

# %% [markdown]
# ### Program 81
# **Task:** Define a class with a generator which can iterate the numbers, which are divisible by 7, between a given range 0 and n.

# %%
# Write your solution here

# %% [markdown]
# ### Program 82
# **Task:** Write a program to compute the frequency of the words from the input sorted alphanumerically.

# %%
# Write your solution here

# %% [markdown]
# ### Program 83
# **Task:** Define a class Person and its two child classes: Male and Female with getGender method.

# %%
# Write your solution here

# %% [markdown]
# ### Program 84
# **Task:** Write a program to generate all sentences where subject is in ["I", "You"], verb is in ["Play", "Love"] and object is in ["Hockey", "Football"].

# %%
# Write your solution here

# %% [markdown]
# ### Program 85
# **Task:** Write a program to compress and decompress strings using zlib.

# %%
# Write your solution here

# %% [markdown]
# ### Program 86
# **Task:** Write a binary search function which searches an item in a sorted list and returns its index.

# %%
# Write your solution here

# %% [markdown]
# ### Program 87
# **Task:** Write a program using generator to print the numbers divisible by 5 and 7 between 0 and n in comma separated form.

# %%
# Write your solution here

# %% [markdown]
# ### Program 88
# **Task:** Write a program using generator to print the even numbers between 0 and n in comma separated form.

# %%
# Write your solution here

# %% [markdown]
# ### Program 89
# **Task:** Write a program using list comprehension to print the Fibonacci Sequence in comma separated form.

# %%
# Write your solution here

# %% [markdown]
# ### Program 90
# **Task:** Write a program to print the user name of a given email address in 'username@companyname.com' format.

# %%
# Write your solution here

# %% [markdown]
# ### Program 91
# **Task:** Define a class named Shape and its subclass Square with area functions.

# %%
# Write your solution here

# %% [markdown]
# ### Program 92
# **Task:** Write a function that stutters a word repeating first two letters twice with an ellipsis and trailing question mark.

# %%
# Write your solution here

# %% [markdown]
# ### Program 93
# **Task:** Create a function that takes an angle in radians and returns the corresponding angle in degrees rounded to one decimal place.

# %%
# Write your solution here

# %% [markdown]
# ### Program 94
# **Task:** Establish if a given integer is a Curzon number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 95
# **Task:** Given the side length x, find the area of a hexagon.

# %%
# Write your solution here

# %% [markdown]
# ### Program 96
# **Task:** Create a function that returns a base-2 (binary) representation of a base-10 (decimal) string number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 97
# **Task:** Create a function that takes three arguments a, b, c and returns the sum of the numbers evenly divided by c from range a, b inclusive.

# %%
# Write your solution here

# %% [markdown]
# ### Program 98
# **Task:** Create a function that returns True if a given inequality expression is correct and False otherwise.

# %%
# Write your solution here

# %% [markdown]
# ### Program 99
# **Task:** Create a function that replaces all the vowels in a string with a specified character.

# %%
# Write your solution here

# %% [markdown]
# ### Program 100
# **Task:** Write a function that calculates the factorial of a number recursively.

# %%
# Write your solution here

# %% [markdown]
# ### Program 101
# **Task:** Create a function that computes the hamming distance between two strings.

# %%
# Write your solution here

# %% [markdown]
# ### Program 102
# **Task:** Create a function that takes a list of non-negative integers and strings and return a new list without the strings.

# %%
# Write your solution here

# %% [markdown]
# ### Program 103
# **Task:** Write a 'Reverser' that takes a string as input and returns that string in reverse order, with the opposite case.

# %%
# Write your solution here

# %% [markdown]
# ### Program 104
# **Task:** Unpack a given list into three variables: first, middle, and last using destructuring assignment.

# %%
# Write your solution here

# %% [markdown]
# ### Program 106
# **Task:** Write a function that moves all elements of one type to the end of the list.

# %%
# Write your solution here

# %% [markdown]
# ### Program 107
# **Task:** Create a function that takes a string and returns a string in which each character is repeated once.

# %%
# Write your solution here

# %% [markdown]
# ### Program 108
# **Task:** Create a function that reverses a boolean value and returns the string 'boolean expected' if another variable type is given.

# %%
# Write your solution here

# %% [markdown]
# ### Program 109
# **Task:** Create a function that returns the thickness (in meters) of a piece of paper after folding it n number of times.

# %%
# Write your solution here

# %% [markdown]
# ### Program 110
# **Task:** Create a function that takes a single string as argument and returns an ordered list containing the indices of all capital letters in the string.

# %%
# Write your solution here

# %% [markdown]
# ### Program 111
# **Task:** Using list comprehensions, create a function that finds all even numbers from 1 to the given number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 112
# **Task:** Create a function that takes a list of strings and integers, and filters out the list so that it returns a list of integers only.

# %%
# Write your solution here

# %% [markdown]
# ### Program 113
# **Task:** Given a list of numbers, create a function which returns the list but with each element's index in the list added to itself.

# %%
# Write your solution here

# %% [markdown]
# ### Program 114
# **Task:** Create a function that takes the height and radius of a cone as arguments and returns the volume of the cone rounded to the nearest hundredth.

# %%
# Write your solution here

# %% [markdown]
# ### Program 115
# **Task:** Write a function that gives the number of dots with its corresponding triangle number of the sequence.

# %%
# Write your solution here

# %% [markdown]
# ### Program 116
# **Task:** Create a function that takes a list of numbers between 1 and 10 (excluding one number) and returns the missing number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 117
# **Task:** Write a function that takes a list and a number as arguments, adds the number to the end, then removes the first element.

# %%
# Write your solution here

# %% [markdown]
# ### Program 118
# **Task:** Create a function that takes a list of dictionaries and returns the sum of people's budgets.

# %%
# Write your solution here

# %% [markdown]
# ### Program 119
# **Task:** Create a function that takes a string and returns a string with its letters in alphabetical order.

# %%
# Write your solution here

# %% [markdown]
# ### Program 120
# **Task:** Create a function that returns the value of an investment at the end of a compounding period rounded to the nearest cent.

# %%
# Write your solution here

# %% [markdown]
# ### Program 121
# **Task:** Write a function that takes a list of elements and returns only the integers.

# %%
# Write your solution here

# %% [markdown]
# ### Program 123
# **Task:** Create a function that takes in two lists and returns True if the second list is the first list shifted to the right by 1.

# %%
# Write your solution here

# %% [markdown]
# ### Program 124
# **Task:** Create a function that takes a list of names and returns the name of the secret society using the first letters sorted.

# %%
# Write your solution here

# %% [markdown]
# ### Program 125
# **Task:** Create a function that checks whether or not a word is an 'isogram'.

# %%
# Write your solution here

# %% [markdown]
# ### Program 126
# **Task:** Create a function that takes a string and returns True or False depending on whether characters are in alphabetical order or not.

# %%
# Write your solution here

# %% [markdown]
# ### Program 127
# **Task:** Create a function that checks whether a number is symmetrical or not.

# %%
# Write your solution here

# %% [markdown]
# ### Program 128
# **Task:** Given a string of numbers separated by a comma and space, return the product of the numbers.

# %%
# Write your solution here

# %% [markdown]
# ### Program 129
# **Task:** Create a function that squares every digit of a number.

# %%
# Write your solution here

# %% [markdown]
# ### Program 130
# **Task:** Create a function that sorts a list and removes all duplicate items from it.

# %%
# Write your solution here

# %% [markdown]
# ### Program 131
# **Task:** Create a function that returns the mean of all digits.

# %%
# Write your solution here

# %% [markdown]
# ### Program 132
# **Task:** Create a function that takes an integer and returns a list from 1 to the given number, amplifying numbers divisible by 4 by 10.

# %%
# Write your solution here

# %% [markdown]
# ### Program 133
# **Task:** Create a function that takes a list of numbers and return the number that's unique.

# %%
# Write your solution here

# %% [markdown]
# ### Program 134
# **Task:** Create a Circle constructor that creates a circle with a radius provided by an argument and has getArea() and getPerimeter() getters.

# %%
# Write your solution here

# %% [markdown]
# ### Program 135
# **Task:** Create a function that takes a list of strings and return a list, sorted from shortest to longest.

# %%
# Write your solution here

# %% [markdown]
# ### Program 136
# **Task:** Create a function that validates whether three given integers form a Pythagorean triplet.

# %%
# Write your solution here

# %% [markdown]
# ### Program 137
# **Task:** Create a function that takes three integer arguments (a, b, c) and returns the amount of integers which are of equal value.

# %%
# Write your solution here

# %% [markdown]
# ### Program 138
# **Task:** Write a function that converts a dictionary into a list of keys-values tuples.

# %%
# Write your solution here

# %% [markdown]
# ### Program 139
# **Task:** Write a function that creates a dictionary with each (key, value) pair being the (lower case, upper case) versions of a letter.

# %%
# Write your solution here

# %% [markdown]
# ### Program 140
# **Task:** Write a function that replaces all vowels in a string with a specified vowel.

# %%
# Write your solution here

# %% [markdown]
# ### Program 141
# **Task:** Create a function that capitalizes a letter if its ASCII code is even and returns lower case if odd.

# %%
# Write your solution here
