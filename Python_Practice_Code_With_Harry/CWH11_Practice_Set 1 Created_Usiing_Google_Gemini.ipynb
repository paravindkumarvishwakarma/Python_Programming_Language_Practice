# %% [markdown]
# # Practice Set 1 - Python Basics (Ultimate Python Course)

# %% [markdown]
# Welcome to your practice set! Every coding question has a dedicated space below it for you to write and run your code.

# %% [markdown]
# ## 📚 Section 1: Multiple Choice Questions (MCQs)
# Double-click this cell or the one below to write your answers (e.g., 1-b, 2-c, etc.)
#
# 1. What is the correct extension for a Python file? (a) .pt (b) .py (c) .pyt (d) .python
# 2. Which of the following is a valid variable name? (a) `1st_name` (b) `first-name` (c) `first_name` (d) `first name`
# 3. What is the output of `type(5)`? (a) `<class 'int'>` (b) `<class 'float'>` (c) `<class 'str'>` (d) `<class 'number'>`
# 4. Which function is used to take input from the user? (a) `get()` (b) `read()` (c) `input()` (d) `scan()`
# 5. How do you insert a single-line comment in Python? (a) `//` (b) `/* */` (c) `#` (d) `<!-- -->`
# 6. What is the output of `print("Code" + "WithHarry")`? (a) Code WithHarry (b) CodeWithHarry (c) Error (d) "Code" "WithHarry"
# 7. Which escape character is used for a new line? (a) `\t` (b) `\n` (c) `\r` (d) `\b`
# 8. What is the result of `10 // 3`? (a) `3.33` (b) `3` (c) `1` (d) `4`
# 9. Which operator is used for exponentiation (power)? (a) `^` (b) `**` (c) `//` (d) `%`
# 10. What is the default data type of the value returned by `input()`? (a) int (b) float (c) str (d) bool
# 11. How do you convert the string `"15"` to an integer? (a) `integer("15")` (b) `int("15")` (c) `str_to_int("15")` (d) `cast("15", int)`
# 12. What will `bool("")` evaluate to? (a) True (b) False (c) Error (d) None
# 13. Which of these is an assignment operator? (a) `==` (b) `=` (c) `!=` (d) `>=`
# 14. What does the `%` operator do? (a) Calculates percentage (b) Divides (c) Returns the remainder (modulo) (d) Multiplies
# 15. Which of the following is a multi-line string/comment? (a) `"This"` (b) `'This'` (c) `'''This'''` (d) `#This#`
# 16. If `a = 10` and `b = "10"`, is `a == b`? (a) True (b) False (c) Error (d) None
# 17. What is the output of `type(3.14)`? (a) `<class 'int'>` (b) `<class 'decimal'>` (c) `<class 'float'>` (d) `<class 'double'>`
# 18. Which statement is used to display output to the screen? (a) `echo` (b) `display` (c) `print()` (d) `write()`
# 19. What does the `\t` escape sequence do? (a) Adds a tab space (b) Adds a newline (c) Adds a backslash (d) Triggers a beep
# 20. In Python, `A = 10` and `a = 10` are the same variable. (a) True (b) False
# 21. What is the output of `print(5 > 3)`? (a) 5 (b) 3 (c) True (d) False
# 22. Which of these is NOT a core data type in Python? (a) string (b) integer (c) float (d) character
# 23. What happens if you run `print(int(4.9))`? (a) 4 (b) 5 (c) 4.9 (d) Error
# 24. Which parameter prevents `print()` from moving to a new line? (a) `stop=""` (b) `end=""` (c) `newline=""` (d) `sep=""`
# 25. How do you specify multiple values in a single print statement? (a) `print("A" + "B")` (b) `print("A", "B")` (c) Both a and b work (d) `print("A" & "B")`

# %% [markdown]
# **Write your MCQ answers below:**
# 1.
# 2.
# 3.

# %% [markdown]
# ## 📤 Section 2: Output-Based Questions
# *Predict the output of the following code snippets. Run them in the code cell to verify.*

# %% [markdown]
# **Question 1:** What is the output of the following?
# `print("Hello", "World", sep="-")`

# %%
# Write your code here to verify Question 1
print("Hello", "World", sep="-")

# %% [markdown]
# **Question 2:** What is the output of the following?
# `print("Harry\nCode")`

# %%
# Write your code here to verify Question 2
print("Harry\nCode")

# %% [markdown]
# **Question 3:** What is the output of the following?
# `print(10 ** 2)`

# %%
# Write your code here to verify Question 3
print(10 ** 2)

# %% [markdown]
# **Question 4:** What is the output of the following?
# `print("5" + "5")`

# %%
# Write your code here to verify Question 4
print("5" + "5")

# %% [markdown]
# **Question 5:** What is the output of the following?
# `print(int("10") + 5)`

# %%
# Write your code here to verify Question 5
print(int("10") + 5)

# %% [markdown]
# **Question 6:** What is the output of the following?
# `print(float(5))`

# %%
# Write your code here to verify Question 6
print(float(5))

# %% [markdown]
# **Question 7:** What is the output of the following?
# `print(type(str(100)))`

# %%
# Write your code here to verify Question 7
print(type(str(100)))

# %% [markdown]
# **Question 8:** What is the output of the following?
# `a = 5; a += 3; print(a)`

# %%
# Write your code here to verify Question 8
a = 5; a += 3; print(a)

# %% [markdown]
# **Question 9:** What is the output of the following?
# `print(10 % 3)`

# %%
# Write your code here to verify Question 9
print(10 % 3)

# %% [markdown]
# **Question 10:** What is the output of the following?
# `print("Python" * 3)`

# %%
# Write your code here to verify Question 10
print("Python" * 3)

# %% [markdown]
# **Question 11:** What is the output of the following?
# `print(bool("False"))`

# %%
# Write your code here to verify Question 11
print(bool("False"))

# %% [markdown]
# **Question 12:** What is the output of the following?
# `print(bool(0))`

# %%
# Write your code here to verify Question 12
print(bool(0))

# %% [markdown]
# **Question 13:** What is the output of the following?
# `a = 15; b = 4; print(a // b)`

# %%
# Write your code here to verify Question 13
a = 15; b = 4; print(a // b)

# %% [markdown]
# **Question 14:** What is the output of the following?
# `print("This is a backslash: \\")`

# %%
# Write your code here to verify Question 14
print("This is a backslash: \\")

# %% [markdown]
# **Question 15:** What is the output of the following?
# `x = 10; y = 10.0; print(x == y)`

# %%
# Write your code here to verify Question 15
x = 10; y = 10.0; print(x == y)

# %% [markdown]
# **Question 16:** What is the output of the following?
# `print('He said, "Python is awesome!"')`

# %%
# Write your code here to verify Question 16
print('He said, "Python is awesome!"')

# %% [markdown]
# **Question 17:** What is the output of the following?
# `print(not True)`

# %%
# Write your code here to verify Question 17
print(not True)

# %% [markdown]
# **Question 18:** What is the output of the following?
# `print(5 != 4)`

# %%
# Write your code here to verify Question 18
print(5 != 4)

# %% [markdown]
# **Question 19:** What is the output of the following?
# `num = 5 # Assume user enters 5 for input\nprint(num * 2)`

# %%
# Write your code here to verify Question 19
num = 5 # Assume user enters 5 for input\nprint(num * 2)

# %% [markdown]
# **Question 20:** What is the output of the following?
# `print(len("Harry"))`

# %%
# Write your code here to verify Question 20
print(len("Harry"))

# %% [markdown]
# **Question 21:** What is the output of the following?
# `a, b = 1, 2; print(a, b)`

# %%
# Write your code here to verify Question 21
a, b = 1, 2; print(a, b)

# %% [markdown]
# **Question 22:** What is the output of the following?
# `print(type(5 / 2))`

# %%
# Write your code here to verify Question 22
print(type(5 / 2))

# %% [markdown]
# **Question 23:** What is the output of the following?
# `print(type(5 // 2))`

# %%
# Write your code here to verify Question 23
print(type(5 // 2))

# %% [markdown]
# **Question 24:** What is the output of the following?
# `print(int(3.999))`

# %%
# Write your code here to verify Question 24
print(int(3.999))

# %% [markdown]
# **Question 25:** What is the output of the following?
# `print("A", end=""); print("B")`

# %%
# Write your code here to verify Question 25
print("A", end=""); print("B")

# %% [markdown]
# ## 🐛 Section 3: Error & Debugging
# *Find the syntax or logical errors in these snippets and fix them in the code cell.*

# %% [markdown]
# **Fix the error 1:**
# `1name = "Harry"`

# %%
# Write your corrected code here
# 1name = "Harry"

# %% [markdown]
# **Fix the error 2:**
# `print("My age is " + 25)`

# %%
# Write your corrected code here
# print("My age is " + 25)

# %% [markdown]
# **Fix the error 3:**
# `a = input("Enter number: "); b = a + 10; print(b)`

# %%
# Write your corrected code here
# a = input("Enter number: "); b = a + 10; print(b)

# %% [markdown]
# **Fix the error 4:**
# `print(Hello World)`

# %%
# Write your corrected code here
# print(Hello World)

# %% [markdown]
# **Fix the error 5:**
# `Class = 10; print(Class)`

# %%
# Write your corrected code here
# Class = 10; print(Class)

# %% [markdown]
# **Fix the error 6:**
# `a = 5; b = 0; print(a / b)`

# %%
# Write your corrected code here
# a = 5; b = 0; print(a / b)

# %% [markdown]
# **Fix the error 7:**
# `print("Harry" - "Code")`

# %%
# Write your corrected code here
# print("Harry" - "Code")

# %% [markdown]
# **Fix the error 8:**
# `int x = 10; print(x)`

# %%
# Write your corrected code here
# int x = 10; print(x)

# %% [markdown]
# **Fix the error 9:**
# `x = "10.5"; y = int(x); print(y)`

# %%
# Write your corrected code here
# x = "10.5"; y = int(x); print(y)

# %% [markdown]
# **Fix the error 10:**
# `# This is a comment print("Hello")`

# %%
# Write your corrected code here
# # This is a comment print("Hello")

# %% [markdown]
# **Fix the error 11:**
# `print('I\'m learning Python') # Notice the quote issues`

# %%
# Write your corrected code here
# print('I\'m learning Python') # Notice the quote issues

# %% [markdown]
# **Fix the error 12:**
# `a = 5; B = 10; print(a + b)`

# %%
# Write your corrected code here
# a = 5; B = 10; print(a + b)

# %% [markdown]
# **Fix the error 13:**
# `type = "String"; print(type(5))`

# %%
# Write your corrected code here
# type = "String"; print(type(5))

# %% [markdown]
# **Fix the error 14:**
# `print(int("Harry"))`

# %%
# Write your corrected code here
# print(int("Harry"))

# %% [markdown]
# **Fix the error 15:**
# `x = 10; x + 5 = y`

# %%
# Write your corrected code here
# x = 10; x + 5 = y

# %% [markdown]
# **Fix the error 16:**
# `print "Hello from Python"`

# %%
# Write your corrected code here
# print "Hello from Python"

# %% [markdown]
# **Fix the error 17:**
# `x = (5 + 3; print(x)`

# %%
# Write your corrected code here
# x = (5 + 3; print(x)

# %% [markdown]
# **Fix the error 18:**
# `a = 5; a++ ; print(a)`

# %%
# Write your corrected code here
# a = 5; a++ ; print(a)

# %% [markdown]
# **Fix the error 19:**
# `x = input("Age: ")
# if x > 18: print("Adult")`

# %%
# Write your corrected code here
# x = input("Age: ")
# if x > 18: print("Adult")

# %% [markdown]
# **Fix the error 20:**
# `print("Harry" * 3.5)`

# %%
# Write your corrected code here
# print("Harry" * 3.5)

# %% [markdown]
# ## ✍️ Section 4: Code Writing
# *Write Python code to solve these problems.*

# %% [markdown]
# 1. Write a program to print "Hello, World!"

# %%
# Write your code here

# %% [markdown]
# 2. Create variables for your name, age, and height, and print them.

# %%
# Write your code here

# %% [markdown]
# 3. Write a program to swap the values of two variables (`a = 5`, `b = 10` becomes `a = 10`, `b = 5`).

# %%
# Write your code here

# %% [markdown]
# 4. Take a user's name as input and print a greeting: "Good Morning, [Name]".

# %%
# Write your code here

# %% [markdown]
# 5. Take two numbers as input and print their sum.

# %%
# Write your code here

# %% [markdown]
# 6. Take a number as input and print its square.

# %%
# Write your code here

# %% [markdown]
# 7. Write a program to calculate the area of a rectangle (Length * Width).

# %%
# Write your code here

# %% [markdown]
# 8. Convert a given temperature in Celsius to Fahrenheit: `F = (C * 9/5) + 32`.

# %%
# Write your code here

# %% [markdown]
# 9. Use escape sequences to print a multi-line address format.

# %%
# Write your code here

# %% [markdown]
# 10. Demonstrate the use of `sep` and `end` parameters in `print()`.

# %%
# Write your code here

# %% [markdown]
# 11. Take a user's age as input and print how old they will be in 10 years.

# %%
# Write your code here

# %% [markdown]
# 12. Perform arithmetic operations (+, -, *, /, //, %, **) on variables `x = 15` and `y = 4`.

# %%
# Write your code here

# %% [markdown]
# 13. Write a program that asks for the user's birth year and calculates their current age.

# %%
# Write your code here

# %% [markdown]
# 14. Write a program to find the remainder when 234 is divided by 7.

# %%
# Write your code here

# %% [markdown]
# 15. Create a program that prompts for hours worked and rate per hour to compute gross pay.

# %%
# Write your code here

# %% [markdown]
# 16. Concatenate three string variables (`first_name`, `middle_name`, `last_name`) with spaces.

# %%
# Write your code here

# %% [markdown]
# 17. Write a program to convert days into hours, minutes, and seconds.

# %%
# Write your code here

# %% [markdown]
# 18. Take a float number as input and cast it to an integer, printing both values.

# %%
# Write your code here

# %% [markdown]
# 19. Assign the same value to three different variables in a single line.

# %%
# Write your code here

# %% [markdown]
# 20. Write a program that repeats a user-inputted word 5 times on the screen.

# %%
# Write your code here

# %% [markdown]
# ## 💡 Section 5: Conceptual Questions
# *Answer these conceptually in the markdown cell below.*

# %% [markdown]
# 1. What is the difference between a Compiler and an Interpreter? Which one does Python use?
# 2. Explain "Dynamic Typing" in Python with an example.
# 3. What are the rules for naming a variable in Python?
# 4. Why can't we use keywords (like `if`, `def`, `class`) as variable names?
# 5. What is the difference between `/` and `//` in Python?
# 6. Explain implicit vs. explicit type casting.
# 7. Why does `input()` always return a string?
# 8. What is the purpose of comments in code?
# 9. How are single-line comments different from multi-line docstrings?
# 10. What is an escape sequence? Give 3 examples.
# 11. Explain what `print("A", "B", sep="---")` does.
# 12. What happens if you multiply a string by an integer? Why?
# 13. Can you divide a string by a number in Python? Why or why not?
# 14. What does the `type()` function do, and why is it useful?
# 15. Explain how the assignment operator `=` works from right to left.
# 16. What is a boolean data type? What values can it hold?
# 17. Why does `0.1 + 0.2` not exactly equal `0.3` in Python floats?
# 18. Explain what an `IndentationError` is.
# 19. What is string concatenation?
# 20. How is Python case-sensitive? Provide an example.

# %% [markdown]
# **Write your conceptual answers here:**
#
# 1.
# 2.

# %% [markdown]
# ## 🌍 Section 6: Real-World Scenarios
# *Apply your skills to these practical situations.*

# %% [markdown]
# 1. **Restaurant Bill:** You ate at a cafe. Food cost 450, tax is 5%. Write a script taking food cost as input, calculating tax, and printing the final bill.

# %%
# Write your code here

# %% [markdown]
# 2. **Currency Converter:** Write a program to convert USD to INR (Assume 1 USD = 83 INR). Take USD as input.

# %%
# Write your code here

# %% [markdown]
# 3. **E-commerce Cart:** An item costs ₹500. Take the quantity as input from the user and print the total cost.

# %%
# Write your code here

# %% [markdown]
# 4. **Login System Prompt:** Write a script that asks for a username and a 4-digit PIN, then prints "Welcome, [Username]!".

# %%
# Write your code here

# %% [markdown]
# 5. **Mileage Calculator:** Ask the user for total kilometers driven and total liters of fuel used. Calculate the car's mileage (km/liter).

# %%
# Write your code here

# %% [markdown]
# 6. **BMI Prep:** Take height (in meters) and weight (in kg) as inputs. Store them in appropriate data types. (Formula: weight / height^2).

# %%
# Write your code here

# %% [markdown]
# 7. **Discount Calculator:** A store offers a flat 20% discount. Take the original price as input and output the discounted price.

# %%
# Write your code here

# %% [markdown]
# 8. **Time Converter:** A YouTube video is given in total seconds (e.g., 345 seconds). Convert and print this as minutes and remaining seconds.

# %%
# Write your code here

# %% [markdown]
# 9. **Salary Split:** A user earns ₹50,000 a month. They save 20%. Calculate how much they save and how much they spend.

# %%
# Write your code here

# %% [markdown]
# 10. **Storage Calculator:** A hard drive has 1024 GB. A single movie takes 1.5 GB. Calculate how many whole movies can fit on the drive using the floor division operator.

# %%
# Write your code here

# %% [markdown]
# ## ⚠️ Section 7: Edge Cases
# *Test the limits of Python's behavior. What happens in these scenarios and why?*

# %% [markdown]
# 1. Casting an empty string to an integer: `int("")`

# %%
# Write your code here

# %% [markdown]
# 2. Casting a space to a boolean: `bool(" ")`

# %%
# Write your code here

# %% [markdown]
# 3. Taking input but just pressing Enter without typing anything. What is stored?

# %%
# Write your code here

# %% [markdown]
# 4. Integer division with negative numbers: `print(-5 // 2)`

# %%
# Write your code here

# %% [markdown]
# 5. Modulo with negative numbers: `print(-5 % 2)`

# %%
# Write your code here

# %% [markdown]
# 6. Multiplying a string by 0 or a negative number: `print("Harry" * 0)`

# %%
# Write your code here

# %% [markdown]
# 7. Reassigning built-in functions: `print = 5; print("Hello")`

# %%
# Write your code here

# %% [markdown]
# 8. Evaluating floating point extremes: `print(99999999999999999.0 + 1)`

# %%
# Write your code here

# %% [markdown]
# 9. Exponentiation of extremely large numbers: `10 ** 1000`

# %%
# Write your code here

# %% [markdown]
# 10. Using escape characters at the very end of a string: `print("Hello\\")`

# %%
# Write your code here

# %% [markdown]
# ## 🚀 Section 8: Mini Projects
# *Combine multiple concepts into a single script.*

# %% [markdown]
# 1. **The Ultimate Tip Calculator:**
# Ask for the bill amount, tip percentage (10, 15, 20), and number of people. Calculate total bill with tip, and amount per person.

# %%
# Write your code here

# %% [markdown]
# 2. **Personal Information Card Generator:**
# Prompt for First Name, Last Name, Age, City, and Profession. Generate a formatted "ID Card" in the terminal.

# %%
# Write your code here

# %% [markdown]
# 3. **Simple Interest Calculator:**
# Ask for Principal, Rate, and Time. Use `SI = (P * R * T) / 100` and output the total interest and final amount.

# %%
# Write your code here

# %% [markdown]
# 4. **Interactive Chatbot (Version 1.0):**
# Sequential script: Bot says Hello, asks name. Responds with greeting, asks birth year, calculates age, prints final message.

# %%
# Write your code here

# %% [markdown]
# 5. **Universal Unit Converter:**
# Take length in cm. Convert to Meters (`cm / 100`), Kilometers (`cm / 100000`), and Inches (`cm / 2.54`). Print all three clearly.

# %%
# Write your code here
