# %% [markdown]
# # 🐍 Practice Set 1 — Ultimate Python Course (Code with Harry)
#
# **Topics Covered:**
# a) Python Basics & Hello World
# b) Variables and Data Types
# c) Type Casting in Python
# d) Taking User Inputs in Python
# e) Comments, Escape Sequences and Print Statement
# f) Operators in Python
#
# | Type | Count |
# |---|---|
# | ✅ MCQs | 25 |
# | 📤 Output-based | 25 |
# | 🐛 Error/Debugging | 20 |
# | ✍️ Code Writing | 20 |
# | 💡 Conceptual | 20 |
# | 🌍 Real-world Scenario | 10 |
# | ⚠️ Edge Cases | 10 |
# | 🚀 Mini Project | 5 |
# | **Total** | **135** |
#
# ---
# **How to use this notebook:**
# - Work through each section in order.
# - For MCQs, write your chosen option letter in the answer cell.
# - For Output-based questions, predict the output *before* running the code cell provided to verify.
# - For Debugging questions, the buggy code is shown as text — type the corrected version into the code cell below it.
# - An **Answer Key** for the MCQ section is provided at the very end — no peeking before you attempt!

# %% [markdown]
# ## ✅ Section 1: Multiple Choice Questions (25)

# %% [markdown]
# **Q1.** Which of the following is the correct way to print `Hello, World!` in Python?
#
# A) print("Hello, World!")
#
# B) echo "Hello, World!"
#
# C) printf("Hello, World!")
#
# D) console.log("Hello, World!")
#
# **Your Answer:** _____

# %% [markdown]
# **Q2.** What will `print(type(5))` output?
#
# A) <class 'int'>
#
# B) <class 'float'>
#
# C) int
#
# D) <class 'number'>
#
# **Your Answer:** _____

# %% [markdown]
# **Q3.** Which data type is used to store True or False values in Python?
#
# A) bool
#
# B) int
#
# C) str
#
# D) bit
#
# **Your Answer:** _____

# %% [markdown]
# **Q4.** What is the result of `10 / 3` in Python 3?
#
# A) 3.3333333333333335
#
# B) 3
#
# C) 3.0
#
# D) Error
#
# **Your Answer:** _____

# %% [markdown]
# **Q5.** What is the result of `10 // 3`?
#
# A) 3
#
# B) 3.33
#
# C) 3.0
#
# D) 1
#
# **Your Answer:** _____

# %% [markdown]
# **Q6.** Which function is used to explicitly convert the string "25" into an integer?
#
# A) int("25")
#
# B) str(25)
#
# C) float("25")
#
# D) integer("25")
#
# **Your Answer:** _____

# %% [markdown]
# **Q7.** What does the `input()` function return by default?
#
# A) A string
#
# B) An integer
#
# C) A float
#
# D) A boolean
#
# **Your Answer:** _____

# %% [markdown]
# **Q8.** Which of these is a valid variable name in Python?
#
# A) _my_var
#
# B) 1var
#
# C) my-var
#
# D) class
#
# **Your Answer:** _____

# %% [markdown]
# **Q9.** What is the output of `print("Hello", "World", sep="-")`?
#
# A) Hello-World
#
# B) Hello World
#
# C) Hello,World
#
# D) Hello - World
#
# **Your Answer:** _____

# %% [markdown]
# **Q10.** Which escape sequence is used for a newline in Python strings?
#
# A) \n
#
# B) \t
#
# C) \\
#
# D) \r
#
# **Your Answer:** _____

# %% [markdown]
# **Q11.** What does `#` represent in Python?
#
# A) Single-line comment
#
# B) Multi-line comment
#
# C) String marker
#
# D) Escape character
#
# **Your Answer:** _____

# %% [markdown]
# **Q12.** What is the correct way to write a docstring / multi-line comment in Python?
#
# A) Triple quotes """ """
#
# B) //
#
# C) /* */
#
# D) <!-- -->
#
# **Your Answer:** _____

# %% [markdown]
# **Q13.** What will `print(2 ** 3)` output?
#
# A) 8
#
# B) 6
#
# C) 9
#
# D) 5
#
# **Your Answer:** _____

# %% [markdown]
# **Q14.** What is the output of `type(3 + 4j)`?
#
# A) <class 'complex'>
#
# B) <class 'float'>
#
# C) <class 'int'>
#
# D) <class 'imaginary'>
#
# **Your Answer:** _____

# %% [markdown]
# **Q15.** Which operator is used to check equality of two values in Python?
#
# A) ==
#
# B) =
#
# C) ===
#
# D) equals()
#
# **Your Answer:** _____

# %% [markdown]
# **Q16.** What is the output of `print(bool(0))`?
#
# A) False
#
# B) True
#
# C) 0
#
# D) Error
#
# **Your Answer:** _____

# %% [markdown]
# **Q17.** What will be the result of `str(10) + str(20)`?
#
# A) "1020"
#
# B) 30
#
# C) Error
#
# D) "30"
#
# **Your Answer:** _____

# %% [markdown]
# **Q18.** What does the `%` operator do?
#
# A) Returns the remainder of division
#
# B) Returns the quotient
#
# C) Multiplies two numbers
#
# D) Converts to percentage
#
# **Your Answer:** _____

# %% [markdown]
# **Q19.** Which of the following correctly takes an integer input from the user?
#
# A) int(input())
#
# B) input(int())
#
# C) input()
#
# D) integer(input())
#
# **Your Answer:** _____

# %% [markdown]
# **Q20.** What is the output of `print(5 == "5")`?
#
# A) False
#
# B) True
#
# C) Error
#
# D) None
#
# **Your Answer:** _____

# %% [markdown]
# **Q21.** Which of the following is NOT a valid Python data type?
#
# A) char
#
# B) int
#
# C) float
#
# D) bool
#
# **Your Answer:** _____

# %% [markdown]
# **Q22.** What is the output of `print("Py" + "thon")`?
#
# A) Python
#
# B) Py thon
#
# C) Error
#
# D) Py+thon
#
# **Your Answer:** _____

# %% [markdown]
# **Q23.** What will `print(10 != 5)` output?
#
# A) True
#
# B) False
#
# C) Error
#
# D) None
#
# **Your Answer:** _____

# %% [markdown]
# **Q24.** What is the output of `print("5" * 3)`?
#
# A) "555"
#
# B) 15
#
# C) Error
#
# D) "5 5 5"
#
# **Your Answer:** _____

# %% [markdown]
# **Q25.** Which of these correctly describes implicit type conversion?
#
# A) Python automatically converts int to float during an operation with a float
#
# B) Using the int() function manually
#
# C) Using the str() function manually
#
# D) Using the float() function manually
#
# **Your Answer:** _____

# %% [markdown]
# ## 📤 Section 2: Output-Based Questions (25)
# Predict the output first, then run the code cell to verify.

# %% [markdown]
# **Q1.** What will be the output of the following code?
#
# ```python
# x = 5
# y = 2
# print(x / y)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
x = 5
y = 2
print(x / y)

# %% [markdown]
# **Q2.** What will be the output of the following code?
#
# ```python
# x = 5
# y = 2
# print(x // y)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
x = 5
y = 2
print(x // y)

# %% [markdown]
# **Q3.** What will be the output of the following code?
#
# ```python
# print(3 + 2 * 2)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(3 + 2 * 2)

# %% [markdown]
# **Q4.** What will be the output of the following code?
#
# ```python
# print((3 + 2) * 2)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print((3 + 2) * 2)

# %% [markdown]
# **Q5.** What will be the output of the following code?
#
# ```python
# a = "10"
# b = 10
# print(a == b)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
a = "10"
b = 10
print(a == b)

# %% [markdown]
# **Q6.** What will be the output of the following code?
#
# ```python
# print(type(10.0))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(type(10.0))

# %% [markdown]
# **Q7.** What will be the output of the following code?
#
# ```python
# x = 10
# x = "Hello"
# print(type(x))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
x = 10
x = "Hello"
print(type(x))

# %% [markdown]
# **Q8.** What will be the output of the following code?
#
# ```python
# print("Hello\tWorld")
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print("Hello\tWorld")

# %% [markdown]
# **Q9.** What will be the output of the following code?
#
# ```python
# print('It\'s a sunny day')
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print('It\'s a sunny day')

# %% [markdown]
# **Q10.** What will be the output of the following code?
#
# ```python
# print(r"C:\newfolder\test")
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(r"C:\newfolder\test")

# %% [markdown]
# **Q11.** What will be the output of the following code?
#
# ```python
# a, b = 5, 10
# a, b = b, a
# print(a, b)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
a, b = 5, 10
a, b = b, a
print(a, b)

# %% [markdown]
# **Q12.** What will be the output of the following code?
#
# ```python
# print(2 ** 3 ** 2)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(2 ** 3 ** 2)

# %% [markdown]
# **Q13.** What will be the output of the following code?
#
# ```python
# print(10 % 3)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(10 % 3)

# %% [markdown]
# **Q14.** What will be the output of the following code?
#
# ```python
# print(-10 % 3)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(-10 % 3)

# %% [markdown]
# **Q15.** What will be the output of the following code?
#
# ```python
# print(bool(""))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(bool(""))

# %% [markdown]
# **Q16.** What will be the output of the following code?
#
# ```python
# print(bool("False"))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(bool("False"))

# %% [markdown]
# **Q17.** What will be the output of the following code?
#
# ```python
# print(int(7.9))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(int(7.9))

# %% [markdown]
# **Q18.** What will be the output of the following code?
#
# ```python
# print(round(7.5))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(round(7.5))

# %% [markdown]
# **Q19.** What will be the output of the following code?
#
# ```python
# print(round(2.5))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(round(2.5))

# %% [markdown]
# **Q20.** What will be the output of the following code?
#
# ```python
# x = 5
# print(x, "is odd" if x % 2 != 0 else "is even")
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
x = 5
print(x, "is odd" if x % 2 != 0 else "is even")

# %% [markdown]
# **Q21.** What will be the output of the following code?
#
# ```python
# print("5" + "5")
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print("5" + "5")

# %% [markdown]
# **Q22.** What will be the output of the following code?
#
# ```python
# print(5 + int("5"))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(5 + int("5"))

# %% [markdown]
# **Q23.** What will be the output of the following code?
#
# ```python
# name = "Harry"
# age = 25
# print(f"{name} is {age} years old")
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
name = "Harry"
age = 25
print(f"{name} is {age} years old")

# %% [markdown]
# **Q24.** What will be the output of the following code?
#
# ```python
# print(1 == 1.0)
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(1 == 1.0)

# %% [markdown]
# **Q25.** What will be the output of the following code?
#
# ```python
# print(type(input))
# ```
#
# **Your Predicted Output:** _____

# %%
# Verify your prediction by running this code
print(type(input))

# %% [markdown]
# ## 🐛 Section 3: Error / Debugging Questions (20)
# Each snippet below has a bug. Identify the error, explain it briefly, then write the corrected code in the cell below.

# %% [markdown]
# **Q1.** Find and explain the bug in the following code:
#
# ```python
# print("Hello World)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q2.** Find and explain the bug in the following code:
#
# ```python
# x = 5
# y = "10"
# print(x + y)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q3.** Find and explain the bug in the following code:
#
# ```python
# name = input("Enter your name: )
# print(name)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q4.** Find and explain the bug in the following code:
#
# ```python
# age = input("Enter age: ")
# print(age + 5)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q5.** Find and explain the bug in the following code:
#
# ```python
# 1age = 25
# print(1age)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q6.** Find and explain the bug in the following code:
#
# ```python
# print("Sum is: " + 10)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q7.** Find and explain the bug in the following code:
#
# ```python
# x = 10
#  y = 20
# print(x + y)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q8.** Find and explain the bug in the following code:
#
# ```python
# print('It's raining')
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q9.** Find and explain the bug in the following code:
#
# ```python
# a = 5
# b = 0
# print(a / b)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q10.** Find and explain the bug in the following code:
#
# ```python
# print("Value:, x)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q11.** Find and explain the bug in the following code:
#
# ```python
# x = int("abc")
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q12.** Find and explain the bug in the following code:
#
# ```python
# Print("Hello")
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q13.** Find and explain the bug in the following code:
#
# ```python
# x = 5
# if x = 5:
#     print("Five")
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q14.** Find and explain the bug in the following code:
#
# ```python
# this is a comment without a hash
# print("Hello")
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q15.** Find and explain the bug in the following code:
#
# ```python
# name = "Harry
# print(name)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q16.** Find and explain the bug in the following code:
#
# ```python
# x = 10
# y = 5
# print(x // y // 0)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q17.** Find and explain the bug in the following code:
#
# ```python
# print(f"Value is {x}")
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q18.** Find and explain the bug in the following code:
#
# ```python
# a = 10
# b = "20"
# print(a - int(b)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q19.** Find and explain the bug in the following code:
#
# ```python
# temperature = input("Enter temperature: ")
# if temperature > 30:
#     print("Hot")
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# **Q20.** Find and explain the bug in the following code:
#
# ```python
# x = 5
# y = 2
# result = x %% y
# print(result)
# ```
#
# **Bug explanation:** _____

# %%
# Write the corrected code here

# %% [markdown]
# ## ✍️ Section 4: Code Writing Questions (20)

# %% [markdown]
# **Q1.** Write a program to swap two numbers without using a third variable.

# %%
# Write your solution here

# %% [markdown]
# **Q2.** Write a program that takes the user's name and age as input and prints a formatted sentence using an f-string.

# %%
# Write your solution here

# %% [markdown]
# **Q3.** Write a program to convert Celsius to Fahrenheit (take Celsius as input from the user).

# %%
# Write your solution here

# %% [markdown]
# **Q4.** Write a program to calculate the area and perimeter of a rectangle (take length and width as input).

# %%
# Write your solution here

# %% [markdown]
# **Q5.** Write a program that takes a number and prints whether it is even or odd.

# %%
# Write your solution here

# %% [markdown]
# **Q6.** Write a program to calculate simple interest given principal, rate, and time as inputs.

# %%
# Write your solution here

# %% [markdown]
# **Q7.** Write a program that takes two numbers as input and prints their sum, difference, product, and quotient.

# %%
# Write your solution here

# %% [markdown]
# **Q8.** Write a program to convert a given number of seconds into hours, minutes, and seconds.

# %%
# Write your solution here

# %% [markdown]
# **Q9.** Write a program that takes marks of 3 subjects and calculates the total and percentage.

# %%
# Write your solution here

# %% [markdown]
# **Q10.** Write a program to check whether a given year is a leap year or not.

# %%
# Write your solution here

# %% [markdown]
# **Q11.** Write a program to take a string input and print its length, uppercase, and lowercase versions.

# %%
# Write your solution here

# %% [markdown]
# **Q12.** Write a program to calculate the compound interest given principal, rate, and time.

# %%
# Write your solution here

# %% [markdown]
# **Q13.** Write a program to take radius as input and calculate the area and circumference of a circle.

# %%
# Write your solution here

# %% [markdown]
# **Q14.** Write a program to reverse a 3-digit number using arithmetic operators only (no string slicing).

# %%
# Write your solution here

# %% [markdown]
# **Q15.** Write a program to take a temperature in Fahrenheit and convert it to Kelvin.

# %%
# Write your solution here

# %% [markdown]
# **Q16.** Write a program that asks for the price of an item and quantity, then calculates the total bill with 18% GST added.

# %%
# Write your solution here

# %% [markdown]
# **Q17.** Write a program to demonstrate all arithmetic operators (+, -, *, /, //, %, **) with two user-input numbers, printing results with labels.

# %%
# Write your solution here

# %% [markdown]
# **Q18.** Write a program that takes a person's weight (kg) and height (m), calculates their BMI, and prints the value.

# %%
# Write your solution here

# %% [markdown]
# **Q19.** Write a program that takes a number and prints its type (int, float, or complex) using type().

# %%
# Write your solution here

# %% [markdown]
# **Q20.** Write a program to swap the values of two variables using Python's tuple unpacking method.

# %%
# Write your solution here

# %% [markdown]
# ## 💡 Section 5: Conceptual Questions (20)

# %% [markdown]
# **Q1.** What is the difference between `=` and `==` in Python?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q2.** Explain the difference between mutable and immutable data types with one example each.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q3.** What is dynamic typing in Python? How is it different from static typing?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q4.** Explain the difference between implicit and explicit type conversion (type casting) with examples.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q5.** Why does `input()` always return a string, even when the user enters a number?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q6.** What is the difference between the `/` and `//` operators in Python?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q7.** Explain the difference between the `is` and `==` operators.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q8.** What are escape sequences? Give three examples and explain their use.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q9.** Why can't variable names start with a digit in Python?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q10.** What is the difference between a comment and a docstring in Python?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q11.** Explain operator precedence in Python with an example that uses `+`, `*`, and `()`.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q12.** What is the difference between the `int`, `float`, and `complex` data types?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q13.** What happens when you try to add an integer and a string directly in Python? Why?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q14.** Explain the concept of type casting and name the three most commonly used casting functions.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q15.** What is the difference between the `print()` and `input()` functions?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q16.** What do the `sep` and `end` parameters of the `print()` function do?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q17.** Why is Python called a 'dynamically typed' language?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q18.** What are logical operators in Python? Name them and explain with a short example.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q19.** What is the difference between `and`, `or`, and `not` operators?
#
# **Your Answer:**
#
# _____

# %% [markdown]
# **Q20.** Explain why `0.1 + 0.2 == 0.3` returns False in Python.
#
# **Your Answer:**
#
# _____

# %% [markdown]
# ## 🌍 Section 6: Real-World Scenario Questions (10)

# %% [markdown]
# **Q1.** You're building a billing system for a grocery store. Take the item price and quantity as input, calculate the total cost, and apply a 5% discount if the total exceeds ₹1000.

# %%
# Write your solution here

# %% [markdown]
# **Q2.** You are a teacher who needs to calculate the average marks of a student across 5 subjects and determine if they passed (average >= 40).

# %%
# Write your solution here

# %% [markdown]
# **Q3.** A bank wants a simple program that takes a deposit amount as input and prints the updated balance (starting balance = ₹5000).

# %%
# Write your solution here

# %% [markdown]
# **Q4.** Build a currency converter that takes an amount in USD and converts it to INR (assume 1 USD = 83 INR).

# %%
# Write your solution here

# %% [markdown]
# **Q5.** A fitness app needs to calculate a user's BMI from their weight (kg) and height (m), then print the raw BMI value.

# %%
# Write your solution here

# %% [markdown]
# **Q6.** An e-commerce site needs to calculate shipping cost: free if the order amount is above ₹500, else ₹50, based on user input of order amount.

# %%
# Write your solution here

# %% [markdown]
# **Q7.** A movie ticket booking system needs to calculate the total price for tickets: number of tickets × ₹200, plus 18% GST.

# %%
# Write your solution here

# %% [markdown]
# **Q8.** A temperature monitoring system takes a temperature reading in Celsius and converts it to both Fahrenheit and Kelvin for display.

# %%
# Write your solution here

# %% [markdown]
# **Q9.** A restaurant billing system takes food cost as input and calculates a 10% service tax and 5% GST separately, then shows the final bill.

# %%
# Write your solution here

# %% [markdown]
# **Q10.** An attendance system takes total classes and classes attended as input, and calculates the attendance percentage.

# %%
# Write your solution here

# %% [markdown]
# ## ⚠️ Section 7: Edge Case Questions (10)
# These questions test tricky, easy-to-miss behavior. Try to reason about the answer first, then verify by running code.

# %% [markdown]
# **Q1.** What happens when you divide a number by zero using `/`? What about `//`?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q2.** What is the output of `print(int("10.5"))`? Why does this happen?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q3.** What happens if you try `int("abc")`? What error is raised?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q4.** Is `0.1 + 0.2` exactly equal to `0.3` in Python? Why or why not?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q5.** What happens when you use `input()` and press Enter without typing anything?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q6.** Compare the outputs of `print(5 / 2)`, `print(5 // 2)`, and `print(5 // -2)`.
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q7.** What happens when you try to convert a very large float to an int, e.g., `int(1e20)`?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q8.** What is the output of `print(True + True)`? Explain why this works.
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q9.** What happens when you compare an int and a string using `==`, like `5 == "5"`?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# **Q10.** What is the output of `print("abc" * 0)` and `print("abc" * -1)`?
#
# **Your Answer:** _____

# %%
# Test it here

# %% [markdown]
# ## 🚀 Section 8: Mini Project Questions (5)
# These are slightly larger builds that combine everything you've learned so far — variables, data types, type casting, input, print formatting, and operators.

# %% [markdown]
# ### 🚀 Mini Project 1: Simple Calculator
#
# Take two numbers and an operator (+, -, *, /) as input from the user, and print the result of the operation.
#
# **Requirements:**
# - Take two numbers using `input()` and convert them appropriately.
# - Take the operator as a string input.
# - Use if-elif statements (or direct evaluation) to perform the correct operation.
# - Print the result in a clean, formatted way using an f-string.

# %%
# Write your project code here

# %% [markdown]
# ### 🚀 Mini Project 2: Restaurant Bill Generator
#
# Take the food item cost, number of people, and tip percentage as input. Calculate GST (5%), tip amount, and final bill per person.
#
# **Requirements:**
# - Take food cost, number of people, and tip percentage as input.
# - Calculate GST amount (5% of food cost).
# - Calculate tip amount based on the tip percentage.
# - Calculate the final total and split it evenly per person.
# - Print a neatly formatted bill summary.

# %%
# Write your project code here

# %% [markdown]
# ### 🚀 Mini Project 3: Student Grade Slip
#
# Take a student's name, roll number, and marks in 5 subjects as input. Calculate total, percentage, and print a formatted 'grade slip'.
#
# **Requirements:**
# - Take name, roll number, and 5 subject marks as input.
# - Calculate total marks and percentage.
# - Print a formatted grade slip using f-strings and escape sequences (e.g., \t, \n) to align the output nicely.

# %%
# Write your project code here

# %% [markdown]
# ### 🚀 Mini Project 4: Unit Converter
#
# Build a program that converts a given length in kilometers to meters, centimeters, and inches, all in one run.
#
# **Requirements:**
# - Take only the length in kilometers as input.
# - Convert and print the equivalent value in meters, centimeters, and inches.
# - Use clear, labeled output for each conversion.

# %%
# Write your project code here

# %% [markdown]
# ### 🚀 Mini Project 5: Personal Finance Snapshot
#
# Take monthly income and total monthly expenses as input. Calculate savings, savings percentage, and print a formatted summary.
#
# **Requirements:**
# - Take monthly income and total expenses as input.
# - Calculate savings (income − expenses).
# - Calculate savings percentage relative to income.
# - Print a formatted financial snapshot summary using f-strings.

# %%
# Write your project code here

# %% [markdown]
# ---
# ## 🔑 Answer Key — Section 1 (MCQs)
# Don't check this until you've attempted all 25 MCQs above!

# %% [markdown]
# Q1: A | Q2: A | Q3: A | Q4: A | Q5: A | Q6: A | Q7: A | Q8: A | Q9: A | Q10: A | Q11: A | Q12: A | Q13: A | Q14: A | Q15: A | Q16: A | Q17: A | Q18: A | Q19: A | Q20: A | Q21: A | Q22: A | Q23: A | Q24: A | Q25: A

# %% [markdown]
# ---
# ## 🎉 That's a wrap on Practice Set 1!
#
# Once you've worked through all 135 questions:
# - Revisit any MCQs or debugging questions you got wrong.
# - Re-attempt the mini projects without looking at your first solution, to test retention.
# - Move on to the next topic in your course and start **Practice Set 2**.
