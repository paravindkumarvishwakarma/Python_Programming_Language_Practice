# %% [markdown]
# # 🐍 Python Day 1 — Variables & Data Types
# ### 50 Practice Questions
#
# ---
# **Instructions:** Each question has a code cell below it. Write your answer there and run it!
#
# Topics covered:
# - Variable assignment & naming rules
# - `int`, `float`, `str`, `bool`, `NoneType`
# - `type()` and `isinstance()`
# - Type conversion (casting)
# - String basics
# - Basic arithmetic with variables
#
# ---

# %% [markdown]
# ## 🟢 Section 1: Variable Assignment (Q1–Q10)

# %% [markdown]
# ### Q1. Create a variable called `name` and assign your name to it. Print it.

# %%
name = "Paravind Kumar Vishwakarma"

# %% [markdown]
# ### Q2. Create a variable `age` with the value `20` and a variable `city` with the value `"Mumbai"`. Print both.

# %%
age = 20 #assigned age
city = "Mumbai" #assigned string value

# %% [markdown]
# ### Q3. Assign three variables in a single line: `x = 1`, `y = 2`, `z = 3`. Print their sum.

# %%
x, y, z = 1,2,3
print(x,y,z)
# Out:
# 1 2 3

# %% [markdown]
# ### Q4. Assign the same value `100` to three variables `a`, `b`, and `c` in one line. Print all three.

# %%
a = b = c = 100 #assigned 100 to all three vairables
print(a, b, c)
# Out:
# 100 100 100

# %% [markdown]
# ### Q5. Create a variable `price` with value `49.99`. Reassign it to `59.99`. Print the new value.

# %%
Price = 49.99 #assigning float value in Price container
Price = 59.99 #Now reassigning the value in Price container
print(Price)
# Out:
# 59.99

# %% [markdown]
# ### Q6. Which of these are valid variable names in Python? Test each one.
# ```
# my_var, 2value, _hidden, my-var, Value1, class
# ```

# %%
# Try assigning each variable name and see which ones work
my_var = 1
# 2value = 2    # uncomment to test
_hidden = 3
# my-var = 4   # uncomment to test
Value1 = 5
# class = 6    # uncomment to test
print("Valid ones work without error!")

# %% [markdown]
# ### Q7. Swap the values of two variables `p = 10` and `q = 20` without using a third variable. Print them after swapping.

# %%
p = 10
q = 20
p = p + q
q = p - q
p = p - q
print(p, q)
# Out:
# 20 10

# %% [markdown]
# ### Q8. Create a variable `is_student` and set it to `True`. Print it.

# %%
is_student = True
print(is_student)
# Out:
# True

# %% [markdown]
# ### Q9. Create a variable `result` and assign `None` to it. Print it.

# %%
result = None
print(result)
# Out:
# None

# %% [markdown]
# ### Q10. Create two variables `first_name = "Ada"` and `last_name = "Lovelace"`. Combine them into a variable `full_name` and print it.

# %%
first_name = "Ada"
last_name = "Lovelace"
full_name = first_name + last_name
print(full_name)
# Out:
# AdaLovelace

# %% [markdown]
# ---
# ## 🔵 Section 2: Data Types & `type()` (Q11–Q20)

# %% [markdown]
# ### Q11. Find the data type of each: `42`, `3.14`, `"hello"`, `True`, `None`.

# %%
# Use type() for each
print(type(42))
print(type(3.14))
print(type("hello"))
print(type(True))
print(type(None))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %% [markdown]
# ### Q12. Create a variable for each data type: `int`, `float`, `str`, `bool`. Print each variable with its type.

# %%
int_var = 34
float_var = 5.4
str_var = "Paravind"
bool_val = True
print(f"Int Variable = {int_var} \nFloat Variable = {float_var} \nString Variable = {str_var} \nBool value = {bool_val}")
# Out:
# Int Variable = 34
# Float Variable = 5.4
# String Variable = Paravind
# Bool value = True

# %% [markdown]
# ### Q13. What is the type of `"123"`? Is it the same as `123`? Use `type()` to verify.

# %%
a_value = "123"
print(type(a_value)) #Checking the type of the variable

b_value = 123
print(type(b_value)) #Checking the type of the variable
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ### Q14. Use `isinstance()` to check if `7.5` is a `float`. Print `True` or `False`.

# %%
# Hint: isinstance(value, type)

# %% [markdown]
# ### Q15. Check if the variable `score = 95` is an instance of both `int` and `float`. What do you observe?

# %%
score = 95
# Your code here

# %% [markdown]
# ### Q16. What is the data type of `True + 1`? Run it and explain the result.

# %%
# Your code here

# %% [markdown]
# ### Q17. Create a variable `pi = 3.14159`. Print its type and check if it is a `float`.

# %%
# Your code here

# %% [markdown]
# ### Q18. What is the type of the result of `10 / 2`? What about `10 // 2`? Run both.

# %%
print(type(10 / 2))
print(type(10 // 2))

# %% [markdown]
# ### Q19. Create variables for your `name` (str), `age` (int), `gpa` (float), `graduated` (bool). Print each with its type.

# %%
# Your code here

# %% [markdown]
# ### Q20. What does `type(None)` return? Run it and note the output.

# %%
# Your code here

# %% [markdown]
# ---
# ## 🟡 Section 3: Type Conversion / Casting (Q21–Q30)

# %% [markdown]
# ### Q21. Convert the string `"42"` to an integer. Print the result and its type.

# %%
# Hint: int("42")

# %% [markdown]
# ### Q22. Convert the integer `7` to a float. Print the result.

# %%
# Your code here

# %% [markdown]
# ### Q23. Convert `3.99` to an integer using `int()`. What value do you get? Why?

# %%
# Your code here

# %% [markdown]
# ### Q24. Convert the integer `100` to a string. Concatenate it with `" points"` and print the result.

# %%
# Your code here

# %% [markdown]
# ### Q25. Try converting the string `"hello"` to an integer. What error do you get?

# %%
# Wrap in try-except to see the error message
try:
    int("hello")
except ValueError as e:
    print("Error:", e)

# %% [markdown]
# ### Q26. Convert `0` and `1` to booleans using `bool()`. What values do you get?

# %%
# Your code here

# %% [markdown]
# ### Q27. Convert `True` and `False` to integers. What are the results?

# %%
# Your code here

# %% [markdown]
# ### Q28. A user enters their age as `"25"` (a string). Convert it to `int`, add `5`, and print the result.

# %%
user_age = "25"
# Your code here

# %% [markdown]
# ### Q29. Convert the float `"3.14"` (a string) to a float number. Print and verify its type.

# %%
# Your code here

# %% [markdown]
# ### Q30. What does `bool("")` and `bool("hello")` return? Test and explain.

# %%
# Your code here

# %% [markdown]
# ---
# ## 🟠 Section 4: String Basics (Q31–Q40)

# %% [markdown]
# ### Q31. Create a string variable `greeting = "Hello, World!"`. Print its length using `len()`.

# %%
# Your code here

# %% [markdown]
# ### Q32. Print the first character and the last character of `"Python"`.

# %%
word = "Python"
# Hint: use indexing word[0] and word[-1]

# %% [markdown]
# ### Q33. Use an f-string to print: `"My name is Alice and I am 22 years old."`

# %%
name = "Alice"
age = 22
# Hint: f"My name is {name}..."

# %% [markdown]
# ### Q34. Convert the string `"python is fun"` to uppercase. Then to title case.

# %%
s = "python is fun"
# Hint: .upper() and .title()

# %% [markdown]
# ### Q35. Check if the string `"Hello"` starts with `"He"` and ends with `"lo"`.

# %%
# Hint: .startswith() and .endswith()

# %% [markdown]
# ### Q36. Create a multiline string using triple quotes that spans 3 lines. Print it.

# %%
# Hint: use """..."""

# %% [markdown]
# ### Q37. Repeat the string `"ha"` five times using the `*` operator.

# %%
# Your code here

# %% [markdown]
# ### Q38. Replace `"World"` with `"Python"` in the string `"Hello, World!"`.

# %%
# Hint: .replace()

# %% [markdown]
# ### Q39. Strip the whitespace from `"   hello   "` and print the cleaned string.

# %%
# Hint: .strip()

# %% [markdown]
# ### Q40. Check if `"cat"` is present in the string `"The cat sat on the mat"`.

# %%
# Hint: use the 'in' keyword

# %% [markdown]
# ---
# ## 🔴 Section 5: Mixed & Challenge Questions (Q41–Q50)

# %% [markdown]
# ### Q41. Calculate the area of a rectangle with `width = 5.5` and `height = 3.2`. Print the result with the message: `"Area = <value>"`.

# %%
# Your code here

# %% [markdown]
# ### Q42. A variable `temperature = 98.6` represents temperature in Fahrenheit. Convert it to Celsius using: `C = (F - 32) * 5/9`. Print the result rounded to 2 decimal places.

# %%
temperature = 98.6
# Your code here

# %% [markdown]
# ### Q43. A product costs `₹1200`. Apply a `10%` discount. Store the final price in `discounted_price` and print it.

# %%
price = 1200
discount = 0.10
# Your code here

# %% [markdown]
# ### Q44. Predict the output before running:
# ```python
# x = 5
# x += 3
# x *= 2
# print(x)
# ```

# %%
# Write your prediction as a comment, then run
# Prediction: ?
x = 5
x += 3
x *= 2
print(x)

# %% [markdown]
# ### Q45. Write a program that stores a person's `name`, `age`, and `height` (in meters) as variables. Print a one-line summary using an f-string.

# %%
# Example output: "John is 25 years old and 1.75m tall."

# %% [markdown]
# ### Q46. What happens when you do `"5" + 5` in Python? Try it. Then fix it so it works.

# %%
# Try running it first, then fix it
try:
    result = "5" + 5
except TypeError as e:
    print("Error:", e)
# Now fix:

# %% [markdown]
# ### Q47. Create a variable `big_number = 1_000_000` (Python allows underscores in numbers). Print it and its type.

# %%
# Your code here

# %% [markdown]
# ### Q48. Check whether the variables `a = 10` and `b = 10.0` are equal using `==`. Then check if they are the same type.

# %%
a = 10
b = 10.0
# Are they equal in value?
# Are they the same type?

# %% [markdown]
# ### Q49. Use `input()` to ask the user for their name and age. Store them in variables and print a greeting. *(Note: `input()` always returns a string — cast age to int.)*

# %%
# Your code here
# name = input("Enter your name: ")
# age  = int(input("Enter your age: "))

# %% [markdown]
# ### Q50. 🏆 Mini Project — Personal Info Card
# Store the following in variables: `name`, `age`, `city`, `profession`, `is_employed` (bool), `salary` (float).
# Print a formatted info card like:
# ```
# ========== INFO CARD ==========
# Name       : Riya Sharma
# Age        : 28
# City       : Mumbai
# Profession : Data Analyst
# Employed   : True
# Salary     : ₹75000.00
# ================================
# ```

# %%
# Your mini project here!
name       = "Riya Sharma"
age        = 28
city       = "Mumbai"
profession = "Data Analyst"
is_employed = True
salary     = 75000.0

# Print the formatted card

# %% [markdown]
# ---
# ## ✅ Summary — What You Practiced Today
#
# | Topic | Questions |
# |---|---|
# | Variable assignment & naming | Q1–Q10 |
# | Data types & `type()` / `isinstance()` | Q11–Q20 |
# | Type conversion (casting) | Q21–Q30 |
# | String basics | Q31–Q40 |
# | Mixed & challenge problems | Q41–Q50 |
#
# **Great work! 🎉 See you on Day 2 — Operators & Expressions!**
