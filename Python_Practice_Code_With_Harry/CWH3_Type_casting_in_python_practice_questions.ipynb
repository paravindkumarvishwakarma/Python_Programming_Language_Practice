# %% [markdown]
# # Practice Questions: Type Casting in Python
#
# This notebook contains practice questions on **Type Casting in Python**.
#
# ## Topics Covered
# - Implicit type conversion
# - Explicit type conversion
# - `int()`, `float()`, `str()`, `bool()`, `list()`, `tuple()`, `set()`
# - Input conversion
# - Type errors and debugging
# - Real-world use cases
# - Edge cases
# - Mini project exercises
#
# ## Question Distribution
#
# | Type | No. of Questions |
# |---|---:|
# | MCQs | 25 |
# | Output-based | 25 |
# | Error/Debugging | 20 |
# | Code writing | 20 |
# | Conceptual | 20 |
# | Real-world scenario | 10 |
# | Edge cases | 10 |
# | Mini Project | 5 |

# %% [markdown]
# # MCQs
#
# Choose the correct option for each question.

# %% [markdown]
# ## Q1
#
# What is the output of `print(type(int('10')))`?
#
# A. <class 'int'>
# B. <class 'str'>
# C. <class 'float'>
# D. Error
#
# **Answer:** A

# %% [markdown]
# ## Q2
#
# What is the output of `print(int(5.9))`?
#
# A. 5
# B. 6
# C. 5.9
# D. Error
#
# **Answer:** A

# %% [markdown]
# ## Q3
#
# Which function converts a value to a floating-point number?
#
# A. str()
# B. bool()
# C. float()
# D. list()
#
# **Answer:** C

# %% [markdown]
# ## Q4
#
# What will `bool('False')` return?
#
# A. False
# B. True
# C. Error
# D. 0
#
# **Answer:** B

# %% [markdown]
# ## Q5
#
# What is the output of `print(float(3))`?
#
# A. 3
# B. 3.0
# C. 3.00
# D. Error
#
# **Answer:** B

# %% [markdown]
# ## Q6
#
# Which of these is explicit type casting?
#
# A. `2 + 3.5`
# B. `int('25')`
# C. `5 * 2`
# D. `7 / 2`
#
# **Answer:** B

# %% [markdown]
# ## Q7
#
# What does `str(100)` return?
#
# A. 100
# B. '100'
# C. Error
# D. 100.0
#
# **Answer:** B

# %% [markdown]
# ## Q8
#
# What is the type of `True + 2` in Python?
#
# A. bool
# B. int
# C. float
# D. str
#
# **Answer:** B

# %% [markdown]
# ## Q9
#
# What will `print(int('0012'))` output?
#
# A. 12
# B. 0012
# C. Error
# D. None
#
# **Answer:** A

# %% [markdown]
# ## Q10
#
# Which conversion can fail for the string `'abc'`?
#
# A. str('abc')
# B. int('abc')
# C. bool('abc')
# D. list('abc')
#
# **Answer:** B

# %% [markdown]
# ## Q11
#
# What is the output of `print(bool(0))`?
#
# A. True
# B. False
# C. 0
# D. Error
#
# **Answer:** B

# %% [markdown]
# ## Q12
#
# Which function converts a number to text?
#
# A. `repr()`
# B. `str()`
# C. `int()`
# D. `float()`
#
# **Answer:** B

# %% [markdown]
# ## Q13
#
# What is the output of `print(int(True))`?
#
# A. 0
# B. 1
# C. True
# D. Error
#
# **Answer:** B

# %% [markdown]
# ## Q14
#
# What is the output of `print(float('7'))`?
#
# A. 7
# B. 7.0
# C. Error
# D. 7.00
#
# **Answer:** B

# %% [markdown]
# ## Q15
#
# Which type conversion is commonly used before arithmetic on user input?
#
# A. `int()` or `float()`
# B. `set()`
# C. `tuple()`
# D. `dict()`
#
# **Answer:** A

# %% [markdown]
# ## Q16
#
# What does `list('abc')` return?
#
# A. ['abc']
# B. ['a', 'b', 'c']
# C. ('a', 'b', 'c')
# D. Error
#
# **Answer:** B

# %% [markdown]
# ## Q17
#
# What will `tuple([1, 2, 3])` return?
#
# A. [1, 2, 3]
# B. (1, 2, 3)
# C. {1, 2, 3}
# D. Error
#
# **Answer:** B

# %% [markdown]
# ## Q18
#
# What is the output of `print(int(8.99))`?
#
# A. 8
# B. 9
# C. 8.99
# D. Error
#
# **Answer:** A

# %% [markdown]
# ## Q19
#
# What is the output of `print(bool(''))`?
#
# A. True
# B. False
# C. None
# D. Error
#
# **Answer:** B

# %% [markdown]
# ## Q20
#
# What is the output of `print(set([1, 1, 2]))`?
#
# A. {1, 1, 2}
# B. {1, 2}
# C. [1, 2]
# D. Error
#
# **Answer:** B

# %% [markdown]
# ## Q21
#
# Which statement is correct about Python type casting?
#
# A. It always happens automatically
# B. It never happens automatically
# C. It can be implicit or explicit
# D. It only works with strings
#
# **Answer:** C

# %% [markdown]
# ## Q22
#
# What is the output of `print(int('10') + int('20'))`?
#
# A. 30
# B. 1020
# C. Error
# D. 20
#
# **Answer:** A

# %% [markdown]
# ## Q23
#
# Which conversion is used to check whether a value is truthy or falsy?
#
# A. `bool()`
# B. `int()`
# C. `float()`
# D. `str()`
#
# **Answer:** A

# %% [markdown]
# ## Q24
#
# What is the output of `print(str(12.5))`?
#
# A. 12.5
# B. '12.5'
# C. 12
# D. Error
#
# **Answer:** A

# %% [markdown]
# ## Q25
#
# What does `int(float('6.0'))` return?
#
# A. 6
# B. 6.0
# C. Error
# D. 0
#
# **Answer:** A

# %% [markdown]
# # Output-Based Questions
#
# Predict the output of each code snippet.

# %% [markdown]
# ## Q1
#
# Predict the output of the following code:

# %%
x = '7'
y = int(x)
print(y + 3)

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q2
#
# Predict the output of the following code:

# %%
a = 10
b = float(a)
print(type(b))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q3
#
# Predict the output of the following code:

# %%
print(int(4.8))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q4
#
# Predict the output of the following code:

# %%
name = 123
print(str(name) + '45')

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q5
#
# Predict the output of the following code:

# %%
value = ''
print(bool(value))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q6
#
# Predict the output of the following code:

# %%
print(int(True) + int(False))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q7
#
# Predict the output of the following code:

# %%
num = '15'
print(float(num))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q8
#
# Predict the output of the following code:

# %%
items = list('hi')
print(items)

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q9
#
# Predict the output of the following code:

# %%
print(bool('python'))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q10
#
# Predict the output of the following code:

# %%
print(int('0010') + 5)

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q11
#
# Predict the output of the following code:

# %%
price = '99.99'
print(type(float(price)))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q12
#
# Predict the output of the following code:

# %%
print(str(3.14159)[:4])

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q13
#
# Predict the output of the following code:

# %%
x = 6
print(type(str(x)))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q14
#
# Predict the output of the following code:

# %%
print(float(5) / 2)

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q15
#
# Predict the output of the following code:

# %%
x = '8'
y = '2'
print(int(x) * int(y))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q16
#
# Predict the output of the following code:

# %%
print(bool([0]))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q17
#
# Predict the output of the following code:

# %%
print(len(str(1000)))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q18
#
# Predict the output of the following code:

# %%
data = tuple('ab')
print(data)

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q19
#
# Predict the output of the following code:

# %%
print(int(float('9.0')))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q20
#
# Predict the output of the following code:

# %%
print(type(bool(1)))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q21
#
# Predict the output of the following code:

# %%
score = '45'
print(int(score) >= 40)

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q22
#
# Predict the output of the following code:

# %%
print(set('book'))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q23
#
# Predict the output of the following code:

# %%
x = 0
print(bool(x))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q24
#
# Predict the output of the following code:

# %%
print(int('12') / 2)

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# ## Q25
#
# Predict the output of the following code:

# %%
print(type(list((1, 2, 3))))

# %% [markdown]
# **Write your answer below.**

# %% [markdown]
# # Error / Debugging Questions
#
# Find and fix the issue in each snippet.

# %% [markdown]
# ## Q1
#
# The following code contains an error or logic issue. Fix it:

# %%
num = int('12.5')
print(num)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q2
#
# The following code contains an error or logic issue. Fix it:

# %%
text = '100'
result = text + 20
print(result)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q3
#
# The following code contains an error or logic issue. Fix it:

# %%
value = float('abc')
print(value)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q4
#
# The following code contains an error or logic issue. Fix it:

# %%
flag = bool('False')
if flag == False:
    print('No')

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q5
#
# The following code contains an error or logic issue. Fix it:

# %%
price = int('99.99')
print(price)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q6
#
# The following code contains an error or logic issue. Fix it:

# %%
x = '5'
y = 2
print(x * y + 1)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q7
#
# The following code contains an error or logic issue. Fix it:

# %%
items = list(123)
print(items)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q8
#
# The following code contains an error or logic issue. Fix it:

# %%
total = int(input('Enter total: '))
print(total + '5')

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q9
#
# The following code contains an error or logic issue. Fix it:

# %%
a = '10'
b = '20'
print(a + b + 5)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q10
#
# The following code contains an error or logic issue. Fix it:

# %%
amount = float('45')
print(amount / '5')

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q11
#
# The following code contains an error or logic issue. Fix it:

# %%
x = None
print(int(x))

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q12
#
# The following code contains an error or logic issue. Fix it:

# %%
nums = tuple(5)
print(nums)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q13
#
# The following code contains an error or logic issue. Fix it:

# %%
print(bool([]) == True)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q14
#
# The following code contains an error or logic issue. Fix it:

# %%
rating = int('4.5')
print(rating)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q15
#
# The following code contains an error or logic issue. Fix it:

# %%
name = str(101)
print(name + 1)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q16
#
# The following code contains an error or logic issue. Fix it:

# %%
value = '  '
print(int(value))

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q17
#
# The following code contains an error or logic issue. Fix it:

# %%
x = '8'
print(x / 2)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q18
#
# The following code contains an error or logic issue. Fix it:

# %%
data = set('aaab')
print(data[0])

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q19
#
# The following code contains an error or logic issue. Fix it:

# %%
x = float(True)
print(x + '1')

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q20
#
# The following code contains an error or logic issue. Fix it:

# %%
print(int('0x10'))

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# # Code Writing Questions
#
# Write the Python code for each problem.

# %% [markdown]
# ## Q1
#
# Take a number as input in string form and print its integer value.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q2
#
# Take a decimal number as input and print its floor integer value using type casting.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q3
#
# Convert a list of strings into a single comma-separated string.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q4
#
# Convert a string into a list of characters.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q5
#
# Read two numbers as strings, cast them, and print their sum.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q6
#
# Convert user input to float and check whether it is greater than 50.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q7
#
# Convert a tuple into a list and display the result.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q8
#
# Convert a list into a set and remove duplicates.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q9
#
# Take a boolean-like input such as `yes` or `no` and convert it into a boolean value.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q10
#
# Convert a number into a string and concatenate it with another string.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q11
#
# Accept age as string input and print whether the person is eligible for voting.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q12
#
# Write a program that converts rupees entered as text into an integer and adds GST.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q13
#
# Convert a string price into float and round it to 2 decimal places.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q14
#
# Write a program that converts a list of numbers stored as strings into integers.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q15
#
# Read a percentage value as string and convert it for comparison.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q16
#
# Create a program that safely converts input to integer using try-except.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q17
#
# Convert a numeric string to float, then to int, and display both values.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q18
#
# Take a list of words and convert it into a set of unique words.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q19
#
# Convert a number 0 or 1 into a boolean and print the result.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q20
#
# Write a program that checks whether user input can be cast to int.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# # Conceptual Questions
#
# Answer in your own words.

# %% [markdown]
# ## Q1
#
# What is type casting in Python?
#
# **Your answer:**

# %% [markdown]
# ## Q2
#
# What is the difference between implicit and explicit type conversion?
#
# **Your answer:**

# %% [markdown]
# ## Q3
#
# Why can `int('12.5')` raise an error?
#
# **Your answer:**

# %% [markdown]
# ## Q4
#
# Why does `bool('False')` evaluate to `True`?
#
# **Your answer:**

# %% [markdown]
# ## Q5
#
# When would you use `float()` instead of `int()`?
#
# **Your answer:**

# %% [markdown]
# ## Q6
#
# What is the role of `str()` in type casting?
#
# **Your answer:**

# %% [markdown]
# ## Q7
#
# Why is type casting important when taking user input?
#
# **Your answer:**

# %% [markdown]
# ## Q8
#
# What happens when Python automatically converts `int` to `float`?
#
# **Your answer:**

# %% [markdown]
# ## Q9
#
# What is the difference between `list('abc')` and `['abc']`?
#
# **Your answer:**

# %% [markdown]
# ## Q10
#
# What is the difference between `tuple()` and `list()` conversions?
#
# **Your answer:**

# %% [markdown]
# ## Q11
#
# Why can `set()` be useful after type casting?
#
# **Your answer:**

# %% [markdown]
# ## Q12
#
# How does type casting help in calculations from form inputs?
#
# **Your answer:**

# %% [markdown]
# ## Q13
#
# What is a safe way to handle invalid conversion input?
#
# **Your answer:**

# %% [markdown]
# ## Q14
#
# What is the difference between truthy and falsy values?
#
# **Your answer:**

# %% [markdown]
# ## Q15
#
# Why does `int(True)` return `1`?
#
# **Your answer:**

# %% [markdown]
# ## Q16
#
# Why does `int(False)` return `0`?
#
# **Your answer:**

# %% [markdown]
# ## Q17
#
# What happens if you try to cast `None` to int?
#
# **Your answer:**

# %% [markdown]
# ## Q18
#
# What happens when converting a floating-point number to int?
#
# **Your answer:**

# %% [markdown]
# ## Q19
#
# Why should you validate input before casting?
#
# **Your answer:**

# %% [markdown]
# ## Q20
#
# Explain one real-life use of type casting in billing or banking.
#
# **Your answer:**

# %% [markdown]
# # Real-world Scenario Questions
#
# Explain how type casting is used in practical situations.

# %% [markdown]
# ## Q1
#
# A shopping app receives quantity and price as strings from a form. How would you cast them before calculating the bill?
#
# **Your answer:**

# %% [markdown]
# ## Q2
#
# A salary calculator gets basic pay as text. How would you safely convert it and compute deductions?
#
# **Your answer:**

# %% [markdown]
# ## Q3
#
# A school marksheet app receives marks as text. How would you convert them and calculate total and percentage?
#
# **Your answer:**

# %% [markdown]
# ## Q4
#
# A UPI app gets an amount typed by the user. How would you ensure the amount is in the correct numeric type?
#
# **Your answer:**

# %% [markdown]
# ## Q5
#
# A fitness app records steps and calories from different sources. How can type casting help combine them?
#
# **Your answer:**

# %% [markdown]
# ## Q6
#
# A tax calculator receives GST percentage as a string. How would you use casting in the calculation?
#
# **Your answer:**

# %% [markdown]
# ## Q7
#
# A weather app gets temperature input from an API as text. How would you prepare it for arithmetic?
#
# **Your answer:**

# %% [markdown]
# ## Q8
#
# An inventory system stores item counts as strings. How would you convert and update stock?
#
# **Your answer:**

# %% [markdown]
# ## Q9
#
# A bank form receives account balance as text. How would you validate and convert it before processing?
#
# **Your answer:**

# %% [markdown]
# ## Q10
#
# A report generator needs unique tags from a text field. How would `set()` casting help?
#
# **Your answer:**

# %% [markdown]
# # Edge Case Questions
#
# Think carefully about special inputs and unusual behavior.

# %% [markdown]
# ## Q1
#
# What happens when you cast an empty string to int?
#
# **Your answer:**

# %% [markdown]
# ## Q2
#
# What happens when you cast a string with spaces like `'   '` to int?
#
# **Your answer:**

# %% [markdown]
# ## Q3
#
# What is the result of `bool('0')` and why?
#
# **Your answer:**

# %% [markdown]
# ## Q4
#
# What is the result of `bool(0.0)`?
#
# **Your answer:**

# %% [markdown]
# ## Q5
#
# What happens when you cast `float('nan')` to int?
#
# **Your answer:**

# %% [markdown]
# ## Q6
#
# What happens when you cast a very large numeric string to int?
#
# **Your answer:**

# %% [markdown]
# ## Q7
#
# What happens when you cast `int(True)` and `int(False)`?
#
# **Your answer:**

# %% [markdown]
# ## Q8
#
# What happens when you cast a list with duplicate values to set?
#
# **Your answer:**

# %% [markdown]
# ## Q9
#
# What happens when you cast `None` to bool?
#
# **Your answer:**

# %% [markdown]
# ## Q10
#
# What happens when you cast a negative float like `-3.7` to int?
#
# **Your answer:**

# %% [markdown]
# # Mini Projects
#
# Build small programs using type casting.

# %% [markdown]
# ## Mini Project 1
#
# Create a bill calculator that takes item price and quantity as strings, converts them, and prints the final amount.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 2
#
# Create a percentage calculator that takes marks in string form and prints the result as float and int.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 3
#
# Create a simple age checker that converts age input to int and displays eligibility messages.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 4
#
# Create a currency converter that takes rupees as text and converts it to dollars after casting.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 5
#
# Create a temperature converter that takes Celsius as text, converts it to float, and prints Fahrenheit.
#
# **Write the full program below:**

# %%
# Write your mini project code here
