# %% [markdown]
# # Practice Questions: Type Casting in Python
#
# This notebook contains practice questions on **Type Casting in Python**.
#
# ## Topics Covered
# - Implicit type conversion
# - Explicit type conversion
# - `int()`, `float()`, `str()`, `bool()`, `list()`, `tuple()`, `set()`
# - Input conversion
# - Type errors and debugging
# - Real-world use cases
# - Edge cases
# - Mini project exercises
#
# ## Question Distribution
#
# | Type | No. of Questions |
# |---|---:|
# | MCQs | 25 |
# | Output-based | 25 |
# | Error/Debugging | 20 |
# | Code writing | 20 |
# | Conceptual | 20 |
# | Real-world scenario | 10 |
# | Edge cases | 10 |
# | Mini Project | 5 |

# %% [markdown]
# # MCQs
#
# Choose the correct option for each question.

# %% [markdown]
# ## Q1 What is the output of `print(type(int('10')))`?
#
# A. <class 'int'>
# B. <class 'str'>
# C. <class 'float'>
# D. Error

# %% [markdown]
# Answer: A

# %% [markdown]
# ## Q2 What is the output of `print(int(5.9))`?
#
# A. 5
# B. 6
# C. 5.9
# D. Error

# %% [markdown]
# Answer: A

# %% [markdown]
# ## Q3 Which function converts a value to a floating-point number?
#
# A. str()
# B. bool()
# C. float()
# D. list()

# %% [markdown]
# Answer: c

# %% [markdown]
# ## Q4 What will `bool('False')` return?
#
# A. False
# B. True
# C. Error
# D. 0

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q5 What is the output of `print(float(3))`?
#
# A. 3
# B. 3.0
# C. 3.00
# D. Error

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q6 Which of these is explicit type casting?
#
# A. `2 + 3.5`
# B. `int('25')`
# C. `5 * 2`
# D. `7 / 2`

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q7 What does `str(100)` return?
#
# A. 100
# B. '100'
# C. Error
# D. 100.0

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q8 What is the type of `True + 2` in Python?
#
# A. bool
# B. int
# C. float
# D. str

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q9 What will `print(int('0012'))` output?
#
# A. 12
# B. 0012
# C. Error
# D. None

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q10 Which conversion can fail for the string `'abc'`?
#
# A. str('abc')
# B. int('abc')
# C. bool('abc')
# D. list('abc')

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q11 What is the output of `print(bool(0))`?
#
# A. True
# B. False
# C. 0
# D. Error

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q12 Which function converts a number to text?
#
# A. `repr()`
# B. `str()`
# C. `int()`
# D. `float()`

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q13 What is the output of `print(int(True))`?
#
# A. 0
# B. 1
# C. True
# D. Error

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q14 What is the output of `print(float('7'))`?
#
# A. 7
# B. 7.0
# C. Error
# D. 7.00

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q15 Which type conversion is commonly used before arithmetic on user input?
#
# A. `int()` or `float()`
# B. `set()`
# C. `tuple()`
# D. `dict()`

# %% [markdown]
# Answer: A

# %% [markdown]
# ## Q16 What does `list('abc')` return?
#
# A. ['abc']
# B. ['a', 'b', 'c']
# C. ('a', 'b', 'c')
# D. Error

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q17 What will `tuple([1, 2, 3])` return?
#
# A. [1, 2, 3]
# B. (1, 2, 3)
# C. {1, 2, 3}
# D. Error

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q18 What is the output of `print(int(8.99))`?
#
# A. 8
# B. 9
# C. 8.99
# D. Error

# %% [markdown]
# Answer: A

# %% [markdown]
# ## Q19 What is the output of `print(bool(''))`?
#
# A. True
# B. False
# C. None
# D. Error

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q20 What is the output of `print(set([1, 1, 2]))`?
#
# A. {1, 1, 2}
# B. {1, 2}
# C. [1, 2]
# D. Error

# %% [markdown]
# Answer: A

# %% [markdown]
# ## Q21 Which statement is correct about Python type casting?
#
# A. It always happens automatically
# B. It never happens automatically
# C. It can be implicit or explicit
# D. It only works with strings

# %% [markdown]
# Answer: C

# %% [markdown]
# ## Q22 What is the output of `print(int('10') + int('20'))`?
#
# A. 30
# B. 1020
# C. Error
# D. 20

# %% [markdown]
# Answer: A

# %% [markdown]
# ## Q23 Which conversion is used to check whether a value is truthy or falsy?
#
# A. `bool()`
# B. `int()`
# C. `float()`
# D. `str()`

# %% [markdown]
# Answer: A

# %% [markdown]
# ## Q24 What is the output of `print(str(12.5))`?
#
# A. 12.5
# B. '12.5'
# C. 12
# D. Error

# %% [markdown]
# Answer: B

# %% [markdown]
# ## Q25 What does `int(float('6.0'))` return?
#
# A. 6
# B. 6.0
# C. Error
# D. 0

# %% [markdown]
# Answer: A

# %% [markdown]
# # Output-Based Questions
#
# Predict the output of each code snippet.

# %% [markdown]
# ## Q26 Predict the output of the following code:

# %%
x = '7'
y = int(x)
print(y + 3)

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 10

# %% [markdown]
# ## Q27 Predict the output of the following code:

# %%
a = 10
b = float(a)
print(type(b))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: <class 'float'>

# %% [markdown]
# ## Q28 Predict the output of the following code:

# %%
print(int(4.8))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 4

# %% [markdown]
# ## Q29 Predict the output of the following code:

# %%
name = 123
print(str(name) + '45')

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 12345

# %% [markdown]
# ## Q30 Predict the output of the following code:

# %%
value = ''
print(bool(value))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: False

# %% [markdown]
# ## Q31 Predict the output of the following code:

# %%
print(int(True) + int(False))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 1

# %% [markdown]
# ## Q32 Predict the output of the following code:

# %%
num = '15'
print(float(num))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 15.0

# %% [markdown]
# ## Q33 Predict the output of the following code:

# %%
items = list('hi')
print(items)

# %% [markdown]
# **Write your answer below.**

# %%
"""Answer: Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
NameError: name 'items' is not defined. Did you mean: 'item'?"""

# %% [markdown]
# ## Q34 Predict the output of the following code:

# %%
print(bool('python'))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: True

# %% [markdown]
# ## Q35 Predict the output of the following code:

# %%
print(int('0010') + 5)

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 15

# %% [markdown]
# ## Q36 Predict the output of the following code:

# %%
price = '99.99'
print(type(float(price)))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: <Class 'float'>

# %% [markdown]
# ## Q37 Predict the output of the following code:

# %%
print(str(3.14159)[:4])

# %% [markdown]
# **Write your answer below.**

# %%
3.14

# %% [markdown]
# ## Q38 Predict the output of the following code:

# %%
x = 6
print(type(str(x)))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: <class 'str'>

# %% [markdown]
# ## Q39 Predict the output of the following code:

# %%
print(float(5) / 2)

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 2.5

# %% [markdown]
# ## Q40 Predict the output of the following code:

# %%
x = '8'
y = '2'
print(int(x) * int(y))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 16

# %% [markdown]
# ## Q41 Predict the output of the following code:

# %%
print(bool([0]))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: True

# %% [markdown]
# ## Q42 Predict the output of the following code:

# %%
print(len(str(1000)))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 4

# %% [markdown]
# ## Q43 Predict the output of the following code:

# %%
data = tuple('ab')
print(data)

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: ab

# %% [markdown]
# ## Q44 Predict the output of the following code:

# %%
print(int(float('9.0')))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 9

# %% [markdown]
# ## Q45 Predict the output of the following code:

# %%
print(type(bool(1)))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: <class 'bool'>

# %% [markdown]
# ## Q46 Predict the output of the following code:

# %%
score = '45'
print(int(score) >= 40)

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: True

# %% [markdown]
# ## Q47 Predict the output of the following code:

# %%
print(set('book'))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: {'b','o','o','k'}

# %% [markdown]
# ## Q4 Predict the output of the following code:

# %%
x = 0
print(bool(x))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: False

# %% [markdown]
# ## Q49 Predict the output of the following code:

# %%
print(int('12') / 2)

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: 6

# %% [markdown]
# ## Q50 Predict the output of the following code:

# %%
print(type(list((1, 2, 3))))

# %% [markdown]
# **Write your answer below.**

# %%
#Answer: <class 'list'>

# %% [markdown]
# # Error / Debugging Questions
#
# Find and fix the issue in each snippet.

# %% [markdown]
# ## Q51 The following code contains an error or logic issue. Fix it:

# %%
num = int('12.5')
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_851/2802796800.py in <cell line: 0>()
# ----> 1 num = int('12.5')
#       2 print(num)
#
# ValueError: invalid literal for int() with base 10: '12.5'

# %% [markdown]
# **Corrected version:**

# %%
num = int(float('12.5'))
print(num)
# Out:
# 12

# %% [markdown]
# ## Q52 The following code contains an error or logic issue. Fix it:

# %%
text = '100'
result = text + 20
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_851/2191654788.py in <cell line: 0>()
#       1 text = '100'
# ----> 2 result = text + 20
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# **Corrected version:**

# %%
text = '100'
result = int(text) + 20
print(result)
# Out:
# 120

# %% [markdown]
# ## Q53 The following code contains an error or logic issue. Fix it:

# %%
value = float('abc')
print(value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_851/3500686233.py in <cell line: 0>()
# ----> 1 value = float('abc')
#       2 print(value)
#
# ValueError: could not convert string to float: 'abc'

# %% [markdown]
# **Corrected version:**

# %%
value = str('abc')
print(value)
# Out:
# abc

# %% [markdown]
# ## Q54 The following code contains an error or logic issue. Fix it:

# %%
flag = bool('False')
if flag == False:
    print('No')

# %% [markdown]
# **Corrected version:**

# %%
flag = bool('')
if flag == False:
  print('No')

# %% [markdown]
# ## Q55 The following code contains an error or logic issue. Fix it:

# %%
price = int('99.99')
print(price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_851/1680560971.py in <cell line: 0>()
# ----> 1 price = int('99.99')
#       2 print(price)
#
# ValueError: invalid literal for int() with base 10: '99.99'

# %% [markdown]
# **Corrected version:**

# %%
price = int(float('99.99'))
print(price)
# Out:
# 99

# %% [markdown]
# ## Q56 The following code contains an error or logic issue. Fix it:

# %%
x = '5'
y = 2
print(x * y + 1)
# Out:
# 11

# %% [markdown]
# **Corrected version:**

# %%
x = '5'
y = 2
print(x * y + 1)

# %% [markdown]
# ## Q57 The following code contains an error or logic issue. Fix it:

# %%
items = list(123)
print(items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_851/3926789618.py in <cell line: 0>()
# ----> 1 items = list(123)
#       2 print(items)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# **Corrected version:**

# %%
items = list(str(123))
print(items)
# Out:
# ['1', '2', '3']

# %% [markdown]
# ## Q58 The following code contains an error or logic issue. Fix it:

# %%
total = int(input('Enter total: '))
print(total + '5')
# Out:
# Enter total: 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_851/3677200150.py in <cell line: 0>()
#       1 total = int(input('Enter total: '))
# ----> 2 print(total + '5')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **Corrected version:**

# %%
total = int(input('Enter total: '))
print(total + int('5'))
# Out:
# Enter total: 15
# 20

# %% [markdown]
# ## Q59 The following code contains an error or logic issue. Fix it:

# %%
a = '10'
b = '20'
print(a + b + 5)

# %% [markdown]
# **Corrected version:**

# %%
a = '10'
b = '20'
print(int(a) + int(b) + 5) #First have to convert string to integar value
# Out:
# 35

# %% [markdown]
# ## Q60 The following code contains an error or logic issue. Fix it:

# %%
amount = float('45')
print(amount / '5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_851/1876012431.py in <cell line: 0>()
#       1 amount = float('45')
# ----> 2 print(amount / '5')
#
# TypeError: unsupported operand type(s) for /: 'float' and 'str'

# %% [markdown]
# **Corrected version:**

# %%
amount = float('45')
print(amount / float('5'))
# Out:
# 9.0

# %% [markdown]
# ## Q61 The following code contains an error or logic issue. Fix it:

# %%
x = None
print(int(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_851/2504371561.py in <cell line: 0>()
#       1 x = None
# ----> 2 print(int(x))
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'NoneType'

# %% [markdown]
# **Corrected version:**

# %%
x = None
print(bool(x))
# Out:
# False

# %% [markdown]
# ## Q62 The following code contains an error or logic issue. Fix it:

# %%
nums = tuple(5)
print(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_851/3892315193.py in <cell line: 0>()
# ----> 1 nums = tuple(5)
#       2 print(nums)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# **Corrected version:**

# %%
nums = tuple(str(5))
print(nums)
# Out:
# ('5',)

# %% [markdown]
# ## Q63 The following code contains an error or logic issue. Fix it:

# %%
print(bool([]) == True)
# Out:
# False

# %% [markdown]
# **Corrected version:**

# %%
print(bool([]) == True)
# Out:
# False

# %% [markdown]
# ## Q64 The following code contains an error or logic issue. Fix it:

# %%
rating = int('4.5')
print(rating)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_851/709447702.py in <cell line: 0>()
# ----> 1 rating = int('4.5')
#       2 print(rating)
#
# ValueError: invalid literal for int() with base 10: '4.5'

# %% [markdown]
# **Corrected version:**

# %%
rating = int(float('4.5'))
print(rating)
# Out:
# 4

# %% [markdown]
# ## Q65
#
# The following code contains an error or logic issue. Fix it:

# %%
name = str(101)
print(name + 1)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q66
#
# The following code contains an error or logic issue. Fix it:

# %%
value = '  '
print(int(value))

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q67
#
# The following code contains an error or logic issue. Fix it:

# %%
x = '8'
print(x / 2)

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q68
#
# The following code contains an error or logic issue. Fix it:

# %%
data = set('aaab')
print(data[0])

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q69
#
# The following code contains an error or logic issue. Fix it:

# %%
x = float(True)
print(x + '1')

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# ## Q70
#
# The following code contains an error or logic issue. Fix it:

# %%
print(int('0x10'))

# %% [markdown]
# **Corrected version:**

# %%
# Write the corrected code here

# %% [markdown]
# # Code Writing Questions
#
# Write the Python code for each problem.

# %% [markdown]
# ## Q71 Take a number as input in string form and print its integer value.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q72 Take a decimal number as input and print its floor integer value using type casting.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q73 Convert a list of strings into a single comma-separated string.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q74 Convert a string into a list of characters.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q75 Read two numbers as strings, cast them, and print their sum.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q76 Convert user input to float and check whether it is greater than 50.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q77 Convert a tuple into a list and display the result.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q78 Convert a list into a set and remove duplicates.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q79 Take a boolean-like input such as `yes` or `no` and convert it into a boolean value.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q80 Convert a number into a string and concatenate it with another string.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q81 Accept age as string input and print whether the person is eligible for voting.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q82 Write a program that converts rupees entered as text into an integer and adds GST.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q83 Convert a string price into float and round it to 2 decimal places.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q84 Write a program that converts a list of numbers stored as strings into integers.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q85 Read a percentage value as string and convert it for comparison.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q86 Create a program that safely converts input to integer using try-except.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q87 Convert a numeric string to float, then to int, and display both values.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q88 Take a list of words and convert it into a set of unique words.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q89 Convert a number 0 or 1 into a boolean and print the result.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# ## Q90 Write a program that checks whether user input can be cast to int.
#
# **Write your solution below:**

# %%
# Write your code here

# %% [markdown]
# # Conceptual Questions
#
# Answer in your own words.

# %% [markdown]
# ## Q91 What is type casting in Python?
#
# **Your answer:**

# %% [markdown]
# ## Q92 What is the difference between implicit and explicit type conversion?
#
# **Your answer:**

# %% [markdown]
# ## Q93 Why can `int('12.5')` raise an error?
#
# **Your answer:**

# %% [markdown]
# ## Q94 Why does `bool('False')` evaluate to `True`?
#
# **Your answer:**

# %% [markdown]
# ## Q95 When would you use `float()` instead of `int()`?
#
# **Your answer:**

# %% [markdown]
# ## Q96 What is the role of `str()` in type casting?
#
# **Your answer:**

# %% [markdown]
# ## Q97 Why is type casting important when taking user input?
#
# **Your answer:**

# %% [markdown]
# ## Q98 What happens when Python automatically converts `int` to `float`?
#
# **Your answer:**

# %% [markdown]
# ## Q99 What is the difference between `list('abc')` and `['abc']`?
#
# **Your answer:**

# %% [markdown]
# ## Q100 What is the difference between `tuple()` and `list()` conversions?
#
# **Your answer:**

# %% [markdown]
# ## Q101 Why can `set()` be useful after type casting?
#
# **Your answer:**

# %% [markdown]
# ## Q102 How does type casting help in calculations from form inputs?
#
# **Your answer:**

# %% [markdown]
# ## Q103 What is a safe way to handle invalid conversion input?
#
# **Your answer:**

# %% [markdown]
# ## Q104 What is the difference between truthy and falsy values?
#
# **Your answer:**

# %% [markdown]
# ## Q105 Why does `int(True)` return `1`?
#
# **Your answer:**

# %% [markdown]
# ## Q106 Why does `int(False)` return `0`?
#
# **Your answer:**

# %% [markdown]
# ## Q107 What happens if you try to cast `None` to int?
#
# **Your answer:**

# %% [markdown]
# ## Q108 What happens when converting a floating-point number to int?
#
# **Your answer:**

# %% [markdown]
# ## Q109 Why should you validate input before casting?
#
# **Your answer:**

# %% [markdown]
# ## Q110 Explain one real-life use of type casting in billing or banking.
#
# **Your answer:**

# %% [markdown]
# # Real-world Scenario Questions
#
# Explain how type casting is used in practical situations.

# %% [markdown]
# ## Q111 A shopping app receives quantity and price as strings from a form. How would you cast them before calculating the bill?
#
# **Your answer:**

# %% [markdown]
# ## Q112 A salary calculator gets basic pay as text. How would you safely convert it and compute deductions?
#
# **Your answer:**

# %% [markdown]
# ## Q113 A school marksheet app receives marks as text. How would you convert them and calculate total and percentage?
#
# **Your answer:**

# %% [markdown]
# ## Q114 A UPI app gets an amount typed by the user. How would you ensure the amount is in the correct numeric type?
#
# **Your answer:**

# %% [markdown]
# ## Q115 A fitness app records steps and calories from different sources. How can type casting help combine them?
#
# **Your answer:**

# %% [markdown]
# ## Q116 A tax calculator receives GST percentage as a string. How would you use casting in the calculation?
#
# **Your answer:**

# %% [markdown]
# ## Q117 A weather app gets temperature input from an API as text. How would you prepare it for arithmetic?
#
# **Your answer:**

# %% [markdown]
# ## Q118 An inventory system stores item counts as strings. How would you convert and update stock?
#
# **Your answer:**

# %% [markdown]
# ## Q119 A bank form receives account balance as text. How would you validate and convert it before processing?
#
# **Your answer:**

# %% [markdown]
# ## Q120 A report generator needs unique tags from a text field. How would `set()` casting help?
#
# **Your answer:**

# %% [markdown]
# # Edge Case Questions
#
# Think carefully about special inputs and unusual behavior.

# %% [markdown]
# ## Q121 What happens when you cast an empty string to int?
#
# **Your answer:**

# %% [markdown]
# ## Q122 What happens when you cast a string with spaces like `'   '` to int?
#
# **Your answer:**

# %% [markdown]
# ## Q123 What is the result of `bool('0')` and why?
#
# **Your answer:**

# %% [markdown]
# ## Q124 What is the result of `bool(0.0)`?
#
# **Your answer:**

# %% [markdown]
# ## Q125 What happens when you cast `float('nan')` to int?
#
# **Your answer:**

# %% [markdown]
# ## Q126 What happens when you cast a very large numeric string to int?
#
# **Your answer:**

# %% [markdown]
# ## Q127 What happens when you cast `int(True)` and `int(False)`?
#
# **Your answer:**

# %% [markdown]
# ## Q128 What happens when you cast a list with duplicate values to set?
#
# **Your answer:**

# %% [markdown]
# ## Q129 What happens when you cast `None` to bool?
#
# **Your answer:**

# %% [markdown]
# ## Q130 What happens when you cast a negative float like `-3.7` to int?
#
# **Your answer:**

# %% [markdown]
# # Mini Projects
#
# Build small programs using type casting.

# %% [markdown]
# ## Mini Project 1
#
# Create a bill calculator that takes item price and quantity as strings, converts them, and prints the final amount.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 2
#
# Create a percentage calculator that takes marks in string form and prints the result as float and int.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 3
#
# Create a simple age checker that converts age input to int and displays eligibility messages.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 4
#
# Create a currency converter that takes rupees as text and converts it to dollars after casting.
#
# **Write the full program below:**

# %%
# Write your mini project code here

# %% [markdown]
# ## Mini Project 5
#
# Create a temperature converter that takes Celsius as text, converts it to float, and prints Fahrenheit.
#
# **Write the full program below:**

# %%
# Write your mini project code here
