# %% [markdown]
# # Type Casting in Python
# ### 50 Practice Questions — Code With Harry Style
# **Topic:** Implicit & Explicit Type Casting | `int()`, `float()`, `str()`, `bool()`, `complex()`

# %% [markdown]
# ### Q1. Convert the string `'42'` to an integer and print its type.

# %%
# Write your code here

# %% [markdown]
# ### Q2. Convert the float `3.99` to an integer. What value do you get and why?

# %%
# Write your code here

# %% [markdown]
# ### Q3. Convert the integer `7` to a float and print the result.

# %%
# Write your code here

# %% [markdown]
# ### Q4. Convert the string `'3.14'` to a float and print its type.

# %%
# Write your code here

# %% [markdown]
# ### Q5. Convert the integer `100` to a string and concatenate it with `' dollars'`.

# %%
# Write your code here

# %% [markdown]
# ### Q6. Convert the boolean `True` to an integer. What is the output?

# %%
# Write your code here

# %% [markdown]
# ### Q7. Convert the boolean `False` to a float. What is the output?

# %%
# Write your code here

# %% [markdown]
# ### Q8. Convert the integer `0` to a boolean. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q9. Convert the integer `5` to a boolean. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q10. Convert the string `'Hello'` to a boolean. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q11. Convert an empty string `''` to a boolean. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q12. Convert the float `0.0` to a boolean. What is the output?

# %%
# Write your code here

# %% [markdown]
# ### Q13. Try converting the string `'abc'` to an integer. What error occurs?

# %%
# Write your code here

# %% [markdown]
# ### Q14. Convert the string `'0'` to a boolean. What is the result and why?

# %%
# Write your code here

# %% [markdown]
# ### Q15. Add an integer `10` and float `5.5` directly. What type is the result? (Implicit Casting)

# %%
# Write your code here

# %% [markdown]
# ### Q16. Convert the integer `255` to a string and check its length.

# %%
# Write your code here

# %% [markdown]
# ### Q17. Use `complex()` to convert the integer `4` to a complex number.

# %%
# Write your code here

# %% [markdown]
# ### Q18. Use `complex(3, 5)` to create a complex number and print its real and imaginary parts.

# %%
# Write your code here

# %% [markdown]
# ### Q19. Take user input (as string) and convert it to an integer to perform addition.

# %%
# Write your code here

# %% [markdown]
# ### Q20. Convert the float `-7.8` to an integer. Does it round or truncate?

# %%
# Write your code here

# %% [markdown]
# ### Q21. Convert the string `'True'` to a boolean using `bool()`. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q22. Convert a list `[1, 2, 3]` to a boolean. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q23. Demonstrate implicit type casting when a boolean is added to an integer.

# %%
# Write your code here

# %% [markdown]
# ### Q24. Convert the string `'99.9'` first to float, then to int. What is the final value?

# %%
# Write your code here

# %% [markdown]
# ### Q25. What happens when you try `int('3.14')` directly (without float conversion first)?

# %%
# Write your code here

# %% [markdown]
# ### Q26. Convert the integer `1` to bool and the integer `0` to bool. Print both results.

# %%
# Write your code here

# %% [markdown]
# ### Q27. Use `str()` to convert a float `2.718` to a string and print its type.

# %%
# Write your code here

# %% [markdown]
# ### Q28. Convert `None` to a boolean. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q29. Multiply a boolean `True` with a float `3.5`. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q30. Create a program that takes a number as a string and checks if it's even or odd after casting.

# %%
# Write your code here

# %% [markdown]
# ### Q31. Convert the binary string `'0b1010'` to an integer using the correct base.

# %%
# Write your code here

# %% [markdown]
# ### Q32. Convert the octal string `'0o17'` to an integer.

# %%
# Write your code here

# %% [markdown]
# ### Q33. Convert the hexadecimal string `'0xFF'` to an integer.

# %%
# Write your code here

# %% [markdown]
# ### Q34. Convert an integer `10` to its binary, octal, and hex string representations.

# %%
# Write your code here

# %% [markdown]
# ### Q35. Add a string number `'50'` and integer `50` using explicit casting. Print the result.

# %%
# Write your code here

# %% [markdown]
# ### Q36. What is the result of `float('inf')` and `float('-inf')` in Python?

# %%
# Write your code here

# %% [markdown]
# ### Q37. Convert `float('nan')` and check its type.

# %%
# Write your code here

# %% [markdown]
# ### Q38. Demonstrate that `int(True)` is `1` and use it in a mathematical expression.

# %%
# Write your code here

# %% [markdown]
# ### Q39. Convert a tuple `(1, 2, 3)` to a boolean. What is the result?

# %%
# Write your code here

# %% [markdown]
# ### Q40. Write a program that safely converts user input to float, handling invalid input with try-except.

# %%
# Write your code here

# %% [markdown]
# ### Q41. What is implicit type casting? Show an example with `int` and `complex`.

# %%
# Write your code here

# %% [markdown]
# ### Q42. Convert a negative float `-0.99` to int. What do you get?

# %%
# Write your code here

# %% [markdown]
# ### Q43. What is the result of `bool(-1)`? Positive integers make sense, but what about negatives?

# %%
# Write your code here

# %% [markdown]
# ### Q44. Convert a dictionary `{'a': 1}` to bool. What about an empty dict `{}`?

# %%
# Write your code here

# %% [markdown]
# ### Q45. Show the type casting hierarchy in Python (widening): `bool → int → float → complex`.

# %%
# Write your code here

# %% [markdown]
# ### Q46. Can you convert a complex number directly to int or float? What error occurs?

# %%
# Write your code here

# %% [markdown]
# ### Q47. Use `str()` to convert a boolean `False` to string. What does the string look like?

# %%
# Write your code here

# %% [markdown]
# ### Q48. Write a program to collect marks as string input, convert to float, and calculate the percentage.

# %%
# Write your code here

# %% [markdown]
# ### Q49. Demonstrate the difference between `int()` (truncation) and `round()` with the same float value.

# %%
# Write your code here

# %% [markdown]
# ### Q50. Write a mini type-casting quiz: take a value, cast it through int → float → str → bool and print result at each step.

# %%
# Write your code here

# %% [markdown]
# ---
# ## 🧪 Mini Project — Smart Type Casting Calculator
# ### Project Description:
# Build a **Smart Type Casting Calculator** that:
# - Accepts any value input from the user (as a string)
# - Detects what type it *could* be (int, float, bool, complex)
# - Casts it into all possible types and displays the results
# - Performs a basic arithmetic operation using the casted values
# - Handles all errors gracefully using try-except
#
# **Concepts Used:** `int()`, `float()`, `str()`, `bool()`, `complex()`, `isinstance()`, `try-except`

# %%
# Write your code here
