# %% [markdown]
# # Practice Set 1 — Ultimate Python Course (CodeWithHarry)
#
# **Topics Covered:**
# - Python Basics (Hello World)
# - Variables and Data Types
# - Type Casting in Python
# - Taking User Inputs
# - Comments, Escape Sequences & Print Statement
# - Operators in Python
#
# ---
#
# | Type | Questions |
# |------|-----------|
# | ✅ MCQs | 25 |
# | 📤 Output-based | 25 |
# | 🐛 Error / Debugging | 20 |
# | ✍️ Code Writing | 20 |
# | 💡 Conceptual | 20 |
# | 🌍 Real-world Scenario | 10 |
# | ⚠️ Edge Cases | 10 |
# | 🚀 Mini Projects | 5 |
# | **📊 Total** | **135** |

# %% [markdown]
# ## ✅ Section 1 — MCQs (25 Questions)

# %% [markdown]
# **Q1.** Which of the following is the correct way to print Hello World in Python?
#
# - A) echo('Hello World')
# - B) print('Hello World')
# - C) printf('Hello World')
# - D) System.out.println('Hello World')

# %% [markdown]
# Anser: B

# %% [markdown]
# **Q2.** Which keyword is used to take input from the user?
#
# - A) scan()
# - B) cin
# - C) input()
# - D) read()

# %% [markdown]
# Answer: C

# %% [markdown]
# **Q3.** What is the default data type returned by input() in Python?
#
# - A) int
# - B) float
# - C) str
# - D) bool

# %% [markdown]
# Answer: C

# %% [markdown]
# **Q4.** Which of these is NOT a valid Python data type?
#
# - A) int
# - B) float
# - C) char
# - D) str

# %% [markdown]
# Answer: C

# %% [markdown]
# **Q5.** What will type(5.0) return?
#
# - A) <class 'int'>
# - B) <class 'float'>
# - C) <class 'str'>
# - D) <class 'double'>

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q6.** Which operator is used for exponentiation in Python?
#
# - A) ^
# - B) **
# - C) //
# - D) %%

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q7.** What does the // operator do?
#
# - A) Division
# - B) Floor Division
# - C) Modulus
# - D) Comment

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q8.** Which symbol is used for single-line comments in Python?
#
# - A) //
# - B) /* */
# - C) #
# - D) --

# %% [markdown]
# Answer: C

# %% [markdown]
# **Q9.** Which escape sequence is used for a newline?
#
# - A) \t
# - B) \n
# - C) \r
# - D) \b

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q10.** What is the output of print(2 + 3 * 4)?
#
# - A) 20
# - B) 14
# - C) 24
# - D) 10

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q11.** Which of the following is a valid variable name?
#
# - A) 1name
# - B) name_1
# - C) name-1
# - D) for

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q12.** What is the correct way to type cast a string '5' to integer?
#
# - A) int('5')
# - B) str(5)
# - C) '5'.int()
# - D) (int)'5'

# %% [markdown]
# Answer: A

# %% [markdown]
# **Q13.** Which operator is used to check equality?
#
# - A) =
# - B) ==
# - C) ===
# - D) !=

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q14.** What is the output of print(10 % 3)?
#
# - A) 3
# - B) 1
# - C) 0
# - D) 3.33

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q15.** Which function is used to check the data type of a variable?
#
# - A) typeof()
# - B) type()
# - C) datatype()
# - D) check()

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q16.** What does \t represent?
#
# - A) Newline
# - B) Tab space
# - C) Backspace
# - D) Null

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q17.** Which of these is a logical operator?
#
# - A) and
# - B) &
# - C) &&
# - D) @

# %% [markdown]
# Answer: A

# %% [markdown]
# **Q18.** What is the output of print('5' + '3')?
#
# - A) 8
# - B) 53
# - C) '8'
# - D) Error

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q19.** What will bool(0) return?
#
# - A) True
# - B) False
# - C) 0
# - D) None

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q20.** Which operator has the highest precedence?
#
# - A) +
# - B) *
# - C) **
# - D) //

# %% [markdown]
# Answer: C

# %% [markdown]
# **Q21.** What is the output of print(type(True))?
#
# - A) <class 'int'>
# - B) <class 'bool'>
# - C) <class 'str'>
# - D) <class 'True'>

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q22.** Which of these is used for multi-line comments (by convention)?
#
# - A) //
# - B) #
# - C) ''' '''
# - D) /* */

# %% [markdown]
# Answer: C

# %% [markdown]
# **Q23.** What will float('3.14') return?
#
# - A) 3
# - B) 3.14
# - C) '3.14'
# - D) Error

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q24.** What is the output of print(7 // 2)?
#
# - A) 3.5
# - B) 3
# - C) 4
# - D) 3.0

# %% [markdown]
# Answer: B

# %% [markdown]
# **Q25.** Which operator is used for assignment?
#
# - A) ==
# - B) =
# - C) :=
# - D) ->

# %% [markdown]
# Answer: B

# %% [markdown]
# ## 📤 Section 2 — Output-based Questions (25)
#
# Predict the output of each code snippet.

# %% [markdown]
# **Q1.** What is the output of the following code?

# %%
print('Hello', 'World')
# Out:
# Hello World

# %% [markdown]
# **Q2.** What is the output of the following code?

# %%
print('Hello' + 'World')
# Out:
# HelloWorld

# %% [markdown]
# **Q3.** What is the output of the following code?

# %%
print('Hello' * 3)
# Out:
# HelloHelloHello

# %% [markdown]
# **Q4.** What is the output of the following code?

# %%
print(2 ** 3)
# Out:
# 8

# %% [markdown]
# **Q5.** What is the output of the following code?

# %%
print(10 / 3)
# Out:
# 3.3333333333333335

# %% [markdown]
# **Q6.** What is the output of the following code?

# %%
print(10 // 3)
# Out:
# 3

# %% [markdown]
# **Q7.** What is the output of the following code?

# %%
print(10 % 3)
# Out:
# 1

# %% [markdown]
# **Q8.** What is the output of the following code?

# %%
print(type(10))
# Out:
# <class 'int'>

# %% [markdown]
# **Q9.** What is the output of the following code?

# %%
print(type(10.5))
# Out:
# <class 'float'>

# %% [markdown]
# **Q10.** What is the output of the following code?

# %%
print(type('10'))
# Out:
# <class 'str'>

# %% [markdown]
# **Q11.** What is the output of the following code?

# %%
print(int(3.7))
# Out:
# 3

# %% [markdown]
# **Q12.** What is the output of the following code?

# %%
print(float(5))
# Out:
# 5.0

# %% [markdown]
# **Q13.** What is the output of the following code?

# %%
print(str(100))
# Out:
# 100

# %% [markdown]
# **Q14.** What is the output of the following code?

# %%
print(bool(''))
# Out:
# False

# %% [markdown]
# **Q15.** What is the output of the following code?

# %%
print(bool('False'))
# Out:
# True

# %% [markdown]
# **Q16.** What is the output of the following code?

# %%
print(5 == 5.0)
# Out:
# True

# %% [markdown]
# **Q17.** What is the output of the following code?

# %%
print(5 == '5')
# Out:
# False

# %% [markdown]
# **Q18.** What is the output of the following code?

# %%
print('a' + 'b' * 2)
# Out:
# abb

# %% [markdown]
# **Q19.** What is the output of the following code?

# %%
print(2 + 3 * 4 - 1)
# Out:
# 13

# %% [markdown]
# **Q20.** What is the output of the following code?

# %%
print((2 + 3) * 4)
# Out:
# 20

# %% [markdown]
# **Q21.** What is the output of the following code?

# %%
x = 5
y = 2
print(x, y, x+y)
# Out:
# 5 2 7

# %% [markdown]
# **Q22.** What is the output of the following code?

# %%
print('Line1\nLine2')
# Out:
# Line1
# Line2

# %% [markdown]
# **Q23.** What is the output of the following code?

# %%
print('Tab\there')
# Out:
# Tab	here

# %% [markdown]
# **Q24.** What is the output of the following code?

# %%
print('It\'s Python')
# Out:
# It's Python

# %% [markdown]
# **Q25.** What is the output of the following code?

# %%
a = 10
b = 3
print(a > b and a < 20)
# Out:
# True

# %% [markdown]
# ## 🐛 Section 3 — Error / Debugging (20)
#
# Find and fix the errors in each code snippet.

# %% [markdown]
# **Q1.** Identify the error and fix the code:

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# **Q2.** Identify the error and fix the code:

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# **Q3.** Identify the error and fix the code:

# %%
x = int(input('Enter number: '))
print(x + 10)
# Out:
# Enter number: 10
# 20

# %% [markdown]
# **Q4.** Identify the error and fix the code:

# %%
name1 = 'Paravind Kumar Vishwakarma'
print(name1)
# Out:
# Paravind Kumar Vishwakarma

# %% [markdown]
# **Q5.** Identify the error and fix the code:

# %%
x = 5
y = int('10')
print(x + y)
# Out:
# 15

# %% [markdown]
# **Q6.** Identify the error and fix the code:

# %%
if x == 5:
    print('five')
# Out:
# five

# %% [markdown]
# **Q7.** Identify the error and fix the code:

# %%
print(10 / 1)
# Out:
# 10.0

# %% [markdown]
# **Q8.** Identify the error and fix the code:

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# **Q9.** Identify the error and fix the code:

# %%
x = str('abc')
print(x)
# Out:
# abc

# %% [markdown]
# **Q10.** Identify the error and fix the code:

# %%
#for = 5 #for is the reserved keyword so we cannot take this as variable

for_value = 5
print(for_value)
# Out:
# 5

# %% [markdown]
# **Q11.** Identify the error and fix the code:

# %%
"""x = 5
print('Value is: ' + x)"""  #In this Code + is replace by "," so print statement will return value

x = 5
print('Value is: ', x)
# Out:
# Value is:  5

# %% [markdown]
# **Q12.** Identify the error and fix the code:

# %%
"""print('Hello'     #Closing Bracket not available in this so this will return error
print('World')"""

print('Hello')
print('World')
# Out:
# Hello
# World

# %% [markdown]
# **Q13.** Identify the error and fix the code:

# %%
#print(5 ** ) No Power value given
print(5 ** 2)
# Out:
# 25

# %% [markdown]
# **Q14.** Identify the error and fix the code:

# %%
"""x, y = 1, 2, 3
print(x, y)"""
x, y, z = 1, 2, 3
print(x, y, z)
# Out:
# 1 2 3

# %% [markdown]
# **Q15.** Identify the error and fix the code:

# %%
#print('Hello" )

print("Hello")
# Out:
# Hello

# %% [markdown]
# **Q16.** Identify the error and fix the code:

# %%
"""a = 10
b = 0 #Divide by Zero value occur
print(a % b)"""

a = 10
b = 2
print(a % b)
# Out:
# 0

# %% [markdown]
# **Q17.** Identify the error and fix the code:

# %%
"""num = input('Enter: ') #Input value taking input as a variable that why system giving type error
sq = num ** 2
print(sq)"""

num = input('Enter: ')
sq = int(num) ** 2
print(sq)
# Out:
# Enter: 10
# 100

# %% [markdown]
# **Q18.** Identify the error and fix the code:

# %%
#print(true) True value stored in lower case
print(True)
# Out:
# True

# %% [markdown]
# **Q19.** Identify the error and fix the code:

# %%
"""x = 5
x++
print(x)"""

x = 5
x = x + 1
print(x)
# Out:
# 6

# %% [markdown]
# **Q20.** Identify the error and fix the code:

# %%
#print('Sum =' 5 + 3) #In this code , comma separator not defined that's why system throwing systax error

print('Sum =',5 + 3)
# Out:
# Sum = 8

# %% [markdown]
# ## ✍️ Section 4 — Code Writing (20)
#
# Write Python code for each of the following.

# %% [markdown]
# **Q1.** Write a program to print 'Hello, World!'.

# %%
# Your code here
print('Hello World') #In this code , print statement is not defined that's why system throwing systax error
# Out:
# Hello World

# %% [markdown]
# **Q2.** Write a program to take a user's name as input and greet them.

# %%
# Your code here
name = input('Enter your name: ')
print(f"Welcome {name}!")
# Out:
# Welcome Paravind Kumar Vishwakarma!

# %% [markdown]
# **Q3.** Write a program to add two numbers entered by the user.

# %%
# Your code here
num1 = int(input('Enter first number: '))
num2 = int(input('Enter second number: '))
sum = num1 + num2
print(f"The sum of {num1} and {num2} is: {sum}")
# Out:
# The sum of 10 and 30 is: 40

# %% [markdown]
# **Q4.** Write a program to swap the values of two variables.

# %%
# Your code here
num1 = int(input('Enter first number: ')) #Taking user input 
num2 = int(input('Enter second number: ')) #Taking user input
num1 = num1 + num2
num2 = num1 - num2
num1 = num1 - num2
print(f"After swapping: num1 = {num1}, num2 = {num2}")
# Out:
# After swapping: num1 = 20, num2 = 10

# %% [markdown]
# **Q5.** Write a program to convert Celsius to Fahrenheit.

# %%
# Your code here
Celsius = float(input("Enter temparature in Celsius: "))
Fahrenheit = (Celsius * 9 / 5) + 32
print(f"Fahrenheit: {Fahrenheit}")
# Out:
# Fahrenheit: 73.75999999999999

# %% [markdown]
# **Q6.** Write a program to calculate the area of a rectangle (take length and width as input).

# %%
# Your code here
Length = float(input("Enter Length: "))
Width = float(input("Enter Breadth: "))
print("Area of Rectangle:",Length * Width)
# Out:
# Area of Rectangle: 200.0

# %% [markdown]
# **Q7.** Write a program to calculate simple interest (P, R, T from user).

# %%
# Your code here

# %% [markdown]
# **Q8.** Write a program to find the square and cube of a number entered by the user.

# %%
# Your code here

# %% [markdown]
# **Q9.** Write a program that takes a float number and prints its integer part.

# %%
# Your code here

# %% [markdown]
# **Q10.** Write a program to check whether a number is even or odd using the modulus operator.

# %%
# Your code here

# %% [markdown]
# **Q11.** Write a program to calculate the average of three numbers.

# %%
# Your code here

# %% [markdown]
# **Q12.** Write a program to convert a string input to an integer and add 10 to it.

# %%
# Your code here

# %% [markdown]
# **Q13.** Write a program to print your name, age and city each on a new line using \n.

# %%
# Your code here

# %% [markdown]
# **Q14.** Write a program to print a multiplication table format using \t (tabs).

# %%
# Your code here

# %% [markdown]
# **Q15.** Write a program to calculate the perimeter of a circle (take radius as input).

# %%
# Your code here

# %% [markdown]
# **Q16.** Write a program to take two numbers and print the result of all arithmetic operators (+, -, *, /, //, %, **).

# %%
# Your code here

# %% [markdown]
# **Q17.** Write a program that takes the price and quantity of an item and prints the total cost.

# %%
# Your code here

# %% [markdown]
# **Q18.** Write a program to convert kilometers to miles.

# %%
# Your code here

# %% [markdown]
# **Q19.** Write a program to check if a number entered by the user is greater than 100.

# %%
# Your code here

# %% [markdown]
# **Q20.** Write a program to print the ASCII value of a character entered by the user (use ord()).

# %%
# Your code here

# %% [markdown]
# ## 💡 Section 5 — Conceptual Questions (20)

# %% [markdown]
# **Q1.** What is Python? Why is it called an interpreted language?

# %% [markdown]
# **Q2.** Explain the difference between print() and input() functions.

# %% [markdown]
# **Q3.** What is a variable? What are the rules for naming variables in Python?

# %% [markdown]
# **Q4.** List and explain the basic data types in Python.

# %% [markdown]
# **Q5.** What is type casting? Explain implicit vs explicit type conversion with examples.

# %% [markdown]
# **Q6.** Explain the difference between int() and float() functions.

# %% [markdown]
# **Q7.** What is the purpose of comments in Python? Explain single-line and multi-line comments.

# %% [markdown]
# **Q8.** What are escape sequences? List any five common escape sequences.

# %% [markdown]
# **Q9.** Explain the difference between / and // operators.

# %% [markdown]
# **Q10.** What are arithmetic, comparison, logical, assignment and bitwise operators? Give one example of each.

# %% [markdown]
# **Q11.** What is operator precedence? Explain with an example.

# %% [markdown]
# **Q12.** What is the difference between == and = in Python?

# %% [markdown]
# **Q13.** Explain the difference between print('a', 'b') and print('a' + 'b').

# %% [markdown]
# **Q14.** What is the difference between mutable and immutable data types?

# %% [markdown]
# **Q15.** Why does input() always return a string?

# %% [markdown]
# **Q16.** What are keywords in Python? Give five examples.

# %% [markdown]
# **Q17.** Explain the use of sep and end parameters in the print() function.

# %% [markdown]
# **Q18.** What is dynamic typing in Python?

# %% [markdown]
# **Q19.** What is the difference between a statement and an expression?

# %% [markdown]
# **Q20.** Explain the role of the interpreter in executing a Python program.

# %% [markdown]
# ## 🌍 Section 6 — Real-world Scenarios (10)

# %% [markdown]
# **Q1.** You are building a billing system. Take the price of an item and quantity from the user and calculate the total bill including 18% GST.

# %%
# Your code here

# %% [markdown]
# **Q2.** A student's marks in 5 subjects are given as input. Calculate the total and percentage.

# %%
# Your code here

# %% [markdown]
# **Q3.** Write a program for a currency converter (INR to USD) — assume 1 USD = 83 INR.

# %%
# Your code here

# %% [markdown]
# **Q4.** A shopkeeper wants to calculate the discounted price. Take original price and discount % as input and print the final price.

# %%
# Your code here

# %% [markdown]
# **Q5.** Take the length and breadth of a room and calculate how many tiles of size 2x2 ft are needed.

# %%
# Your code here

# %% [markdown]
# **Q6.** Take a person's date of birth (year) and calculate their current age.

# %%
# Your code here

# %% [markdown]
# **Q7.** Build a small ATM prompt: take account balance and withdrawal amount and print the remaining balance.

# %%
# Your code here

# %% [markdown]
# **Q8.** Take temperature in Fahrenheit from a weather API user and convert to Celsius.

# %%
# Your code here

# %% [markdown]
# **Q9.** A pizza costs ₹250 and each extra topping ₹40. Take number of toppings from user and calculate total price.

# %%
# Your code here

# %% [markdown]
# **Q10.** Take fuel price per litre and litres purchased and print the total amount to pay.

# %%
# Your code here

# %% [markdown]
# ## ⚠️ Section 7 — Edge Cases (10)

# %% [markdown]
# **Q1.** What happens if you try int('12.5')? Why?

# %% [markdown]
# **Q2.** What is the output of print(0.1 + 0.2)? Why is it not exactly 0.3?

# %% [markdown]
# **Q3.** What happens when you divide a number by 0 using / and //?

# %% [markdown]
# **Q4.** What is the output of bool(' ') vs bool('')? Explain.

# %% [markdown]
# **Q5.** What happens if you use a Python keyword like 'for' or 'if' as a variable name?

# %% [markdown]
# **Q6.** What is the result of print(True + True + False)? Why?

# %% [markdown]
# **Q7.** What happens if you input an empty string and try to convert it to int?

# %% [markdown]
# **Q8.** What is the difference between print('5' * 3) and print(5 * 3)?

# %% [markdown]
# **Q9.** What happens when very large numbers (e.g., 10**1000) are used in Python?

# %% [markdown]
# **Q10.** What is the output of print(type(10/2)) vs print(type(10//2))? Why?

# %% [markdown]
# ## 🚀 Section 8 — Mini Projects (5)

# %% [markdown]
# **Project 1.** **Simple Calculator** — Take two numbers and an operator (+, -, *, /) as input and display the result.

# %%
# Your code here

# %% [markdown]
# **Project 2.** **BMI Calculator** — Take weight (kg) and height (m) from the user and calculate BMI = weight / (height ** 2).

# %%
# Your code here

# %% [markdown]
# **Project 3.** **Tip Calculator** — Take bill amount and tip percentage from the user and calculate tip and total.

# %%
# Your code here

# %% [markdown]
# **Project 4.** **Age in Days Calculator** — Take user's age in years and print approximate age in days, hours and minutes.

# %%
# Your code here

# %% [markdown]
# **Project 5.** **Electricity Bill Calculator** — Take units consumed as input and calculate bill using slabs: first 100 units @ ₹5, next 100 @ ₹7, above 200 @ ₹10.

# %%
# Your code here

# %% [markdown]
# ---
#
# ### ✨ End of Practice Set 1
#
# Keep practicing! — *Ultimate Python Course*
