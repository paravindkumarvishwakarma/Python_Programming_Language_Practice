# %% [markdown]
# #### Q1: Your First Program
# Write a program that prints:

# %%
print("Hello, World! Welcome to Python.")

# %% [markdown]
# #### Q2: Print a Poem
# Write a program that prints the following poem using a single print() statement:
# (Hint: Use \n for a new line.)
# Twinkle, twinkle, little star,
# How I wonder what you are!

# %%
print("Twinkle, twinkle, little star, \nHow I wonder what you are!")
# Out:
# Twinkle, twinkle, little star,
# How I wonder what you are!

# %% [markdown]
# #### Q3: Variables & Data Types
# Create variables to store:
#
# Your name (string)
# Your age (integer)
# Your height in meters (float)
# A boolean value representing whether you are a student
# Print all of them in one line.

# %%
name = "Paravind Kumar Vishwakarma"
age = int(24)
height = 1.78
is_student = True
print("Name = ",name," Age = ",age," Height = ",height," Is_Student = ",is_student)
# Out:
# Name =  Paravind Kumar Vishwakarma  Age =  24  Height =  1.78  Is_Student =  True

# %% [markdown]
# #### Q4: Typecasting Practice
#
# You are given a string:
# num = "45"
# 1. Convert it into an integer
# 2. Add 10 to it
# 3. Print the result

# %%
num = "45"
int_Num = int(num)
print(type(int_Num))
# Out:
# <class 'int'>

# %% [markdown]
# #### Q5: Taking User Input
#
# Write a program that:
# 1. Asks the user for their favorite food.
# 2. Prints:
# Wow! I also like <food>.

# %%
fav_Food = input("Enter your favorite food = ")
print(f"Wow! I also like {fav_Food}")
# Out:
# Wow! I also like Banana

# %% [markdown]
# #### Q6: Simple Calculator
# Write a program that:
#
# a. Takes two numbers as input from the user.
#
# b. Prints their:
#
# 1. Sum
# 2. Difference
# 3. Product
# 4. Quotient

# %%
num1 = float(input("Enter first number = "))
num2 = float(input("Enter second number = "))
sum = print(num1 + num2)
Difference = print(num1 - num2)
Product = print(num1 * num2)
Quotient = print(num1 / num2)
# Out:
# 30.0
# -10.0
# 200.0
# 0.5

# %% [markdown]
# #### Q7: Escape Sequences
# Print the following output using escape sequences:
#
# Hello "Python" World!
# This is on a new line.
# This is a tab →	    after tab.

# %%
print('Hello "Python" World! \nThis is on a new line. \tThis is a tab')
# Out:
# Hello "Python" World!
# This is on a new line. 	This is a tab

# %% [markdown]
# #### Q8: Operator Challenge
# Write a program that:
#
# Takes an integer as input from the user.
# Prints the square and cube of that number.

# %%
int_Num = int(input("Enter a number = "))
print("Square root of the number is  ",int_Num**2,"\nCube of the number is ",int_Num**3)
# Out:
# Square root of the number is   100
# Cube of the number is  1000
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #### Q9: Quick Quiz (True/False)
#
# Mark each as True or False:
#
# 1. Python code must always end with a semicolon ;
# 2. The # symbol is used for comments in Python
# 3. "123" and 123 are the same in Python
# 4. The * operator is used for multiplication
# 5. \n creates a new line
# 6. Variables in Python can start with numbers
# 7. int("10") + 5 gives 15

# %%
#1. False
#2. True
#3. False
#4. True
#5. True
#6. False
#7. True
