# %% [markdown]
# # Practice Set 1
#
# **Python Programming Language**
#
# Covered Topics:
# - Python Basics (Hello World)
# - Variables and Data Types
# - Type Casting
# - User Input
# - Comments, Escape Sequences & Print
# - Operators
#
# **Instructions:**
# - Try solving every question before checking online.
# - Do not execute code mentally only—write it.

# %% [markdown]
# ## ✅ MCQs (25 Questions)

# %% [markdown]
# **Q1.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q2.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q3.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q4.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q5.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q6.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q7.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q8.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q9.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q10.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q11.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q12.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q13.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q14.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q15.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q16.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q17.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q18.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q19.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q20.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q21.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q22.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q23.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q24.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# **Q25.** Create an MCQ about one of the covered topics (Hello World, variables, data types, type casting, user input, comments, escape sequences, print, or operators). Write four options (A–D) and choose the correct answer.

# %%
# Write your answer here

# %% [markdown]
# ## 📤 Output-based (25 Questions)

# %% [markdown]
# **Q1.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q2.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q3.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q4.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q5.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q6.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q7.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q8.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q9.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q10.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q11.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q12.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q13.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q14.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q15.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q16.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q17.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q18.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q19.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q20.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q21.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q22.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q23.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q24.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q25.** Predict the output of a short Python snippet using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# ## 🐛 Error/Debugging (20 Questions)

# %% [markdown]
# **Q1.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q2.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q3.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q4.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q5.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q6.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q7.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q8.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q9.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q10.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q11.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q12.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q13.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q14.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q15.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q16.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q17.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q18.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q19.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q20.** Find and fix the error in a small Python program related to the covered topics.

# %%
# Write your answer here

# %% [markdown]
# ## ✍️ Code Writing (20 Questions)

# %% [markdown]
# **Q1.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q2.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q3.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q4.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q5.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q6.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q7.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q8.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q9.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q10.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q11.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q12.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q13.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q14.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q15.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q16.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q17.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q18.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q19.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# **Q20.** Write a Python program using only the covered topics.

# %%
# Write your answer here

# %% [markdown]
# ## 💡 Conceptual (20 Questions)

# %% [markdown]
# **Q1.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q2.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q3.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q4.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q5.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q6.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q7.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q8.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q9.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q10.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q11.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q12.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q13.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q14.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q15.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q16.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q17.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q18.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q19.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# **Q20.** Explain the concept in your own words with an example.

# %%
# Write your answer here

# %% [markdown]
# ## 🌍 Real-world Scenario (10 Questions)

# %% [markdown]
# **Q1.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q2.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q3.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q4.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q5.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q6.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q7.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q8.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q9.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# **Q10.** Solve a real-world problem using variables, input, and operators.

# %%
# Write your answer here

# %% [markdown]
# ## ⚠️ Edge Cases (10 Questions)

# %% [markdown]
# **Q1.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q2.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q3.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q4.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q5.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q6.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q7.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q8.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q9.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# **Q10.** What happens in an edge case? Explain and, if needed, write code.

# %%
# Write your answer here

# %% [markdown]
# ## 🚀 Mini Project (5 Questions)

# %% [markdown]
# **Project 1.** Build a beginner-friendly mini project using only the covered topics. Include objective, inputs, expected output, and challenge extension.

# %%
# Build your project here

# %% [markdown]
# **Project 2.** Build a beginner-friendly mini project using only the covered topics. Include objective, inputs, expected output, and challenge extension.

# %%
# Build your project here

# %% [markdown]
# **Project 3.** Build a beginner-friendly mini project using only the covered topics. Include objective, inputs, expected output, and challenge extension.

# %%
# Build your project here

# %% [markdown]
# **Project 4.** Build a beginner-friendly mini project using only the covered topics. Include objective, inputs, expected output, and challenge extension.

# %%
# Build your project here

# %% [markdown]
# **Project 5.** Build a beginner-friendly mini project using only the covered topics. Include objective, inputs, expected output, and challenge extension.

# %%
# Build your project here
